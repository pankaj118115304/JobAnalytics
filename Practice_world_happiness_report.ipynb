# %%
import pandas as pd
import numpy as np
import sklearn 
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
whr=pd.read_csv('happiness_score.csv')
whr
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
# to set the columns name 
whr.columns=['Country','Region','Happiness Rank','Happiness Score','Standard Error','Economy','Family','Health','Freedom','Trust','Generosity','Dystopia Residual']

# %%
# to find top 10 data
whr.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy   Family   Health  Freedom    Trust  Generosity  \
# ...

# %%
whr.iloc[11:20]
# Out:
#                  Country                           Region  Happiness Rank  \
# 11            Costa Rica      Latin America and Caribbean              12
# 12               Austria                   Western Europe              13
# 13                Mexico      Latin America and Caribbean              14
# 14         United States                    North America              15
# 15                Brazil      Latin America and Caribbean              16
# 16            Luxembourg                   Western Europe              17
# 17               Ireland                   Western Europe              18
# 18               Belgium                   Western Europe              19
# 19  United Arab Emirates  Middle East and Northern Africa              20
#
#     Happiness Score  Standard Error  Economy   Family   Health  Freedom  \
# 11            7.226         0.04454  0.95578  1.23788  0.86027  0.63376
# 12            7.200         0.03751  1.33723  1.29704  0.89042  0.62433
# ...

# %%
# to find bottom 10 data
whr.tail(10)
# Out:
#           Country                           Region  Happiness Rank  \
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 153        Rwanda               Sub-Saharan Africa             154
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy   Family   Health  Freedom  \
# 148            3.667         0.03830  0.34193  0.76062  0.15010  0.23501
# 149            3.656         0.03590  0.17417  0.46475  0.24009  0.37725
# ...

# %%
whr.shape
# Out:
# (158, 12)

# %%
whr.index
# Out:
# RangeIndex(start=0, stop=158, step=1)

# %%
whr.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error     Economy  \
# count      158.000000       158.000000      158.000000  158.000000
# mean        79.493671         5.375734        0.047885    0.846137
# std         45.754363         1.145010        0.017146    0.403121
# min          1.000000         2.839000        0.018480    0.000000
# 25%         40.250000         4.526000        0.037268    0.545808
# 50%         79.500000         5.232500        0.043940    0.910245
# 75%        118.750000         6.243750        0.052300    1.158448
# max        158.000000         7.587000        0.136930    1.690420
#
#            Family      Health     Freedom       Trust  Generosity  \
# count  158.000000  158.000000  158.000000  158.000000  158.000000
# mean     0.991046    0.630259    0.428615    0.143422    0.237296
# std      0.272369    0.247078    0.150693    0.120034    0.126685
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# ...

# %%
# values counts in Region
whr['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %%
whr['Country'].value_counts()
# Out:
# Haiti         1
# Djibouti      1
# Lithuania     1
# Bangladesh    1
# Taiwan        1
#              ..
# Malaysia      1
# India         1
# Laos          1
# Senegal       1
# Uzbekistan    1
# Name: Country, Length: 158, dtype: int64

# %%
# To find Null value in data
whr.isnull().sum()
# Out:
# Country              0
# Region               0
# Happiness Rank       0
# Happiness Score      0
# Standard Error       0
# Economy              0
# Family               0
# Health               0
# Freedom              0
# Trust                0
# Generosity           0
# Dystopia Residual    0
# dtype: int64

# %%
# To find null value using heatmap 
sns.heatmap(whr.isnull())

# %%
whr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            158 non-null    object
#  1   Region             158 non-null    object
#  2   Happiness Rank     158 non-null    int64
#  3   Happiness Score    158 non-null    float64
#  4   Standard Error     158 non-null    float64
#  5   Economy            158 non-null    float64
#  6   Family             158 non-null    float64
#  7   Health             158 non-null    float64
#  8   Freedom            158 non-null    float64
#  9   Trust              158 non-null    float64
#  10  Generosity         158 non-null    float64
#  11  Dystopia Residual  158 non-null    float64
# dtypes: float64(9), int64(1), object(2)
# memory usage: 14.9+ KB

# %%
# univariate analysis
plt.boxplot(whr['Happiness Rank'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b79c519948>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b79c519fc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b79c519188>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b79c51ff48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b79c51fb48>],
#  'means': []}

# %%
plt.boxplot(whr['Happiness Score'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b79c585b08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b79c585c88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b79c585308>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b79c58bfc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b79c58bd08>],
#  'means': []}

# %%
whr.plot(kind='bar',stacked=True, figsize=(20,5))

# %%
whr.plot.box('Happiness Rank')

# %%
# Biavariate analysis
whr.plot(kind='scatter',x='Happiness Score',y='Economy',stacked=True)

# %%
whr.plot(kind='scatter',stacked=True,x='Happiness Score',y='Health')

# %%
# To find Correlation 
whrc=whr.corr()
whrc
# Out:
#                    Happiness Rank  Happiness Score  Standard Error   Economy  \
# Happiness Rank           1.000000        -0.992105        0.158516 -0.785267
# Happiness Score         -0.992105         1.000000       -0.177254  0.780966
# Standard Error           0.158516        -0.177254        1.000000 -0.217651
# Economy                 -0.785267         0.780966       -0.217651  1.000000
# Family                  -0.733644         0.740605       -0.120728  0.645299
# Health                  -0.735613         0.724200       -0.310287  0.816478
# Freedom                 -0.556886         0.568211       -0.129773  0.370300
# Trust                   -0.372315         0.395199       -0.178325  0.307885
# Generosity              -0.160142         0.180319       -0.088439 -0.010465
# Dystopia Residual       -0.521999         0.530474        0.083981  0.040059
#
#                      Family    Health   Freedom     Trust  Generosity  \
# ...

# %%
sns.heatmap(whrc)

# %%
whr.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B79D976208>,
# ...
#       dtype=object)

# %%
sns.pairplot(whr)

# %%
sns.distplot(whr['Happiness Score'])

# %%
# Use Label encoding to convert the string catagorical value
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
whr['Country']=pd.DataFrame(le.fit_transform(whr['Country']))
whr['Country']
# Out:
# 0      135
# 1       58
# 2       37
# 3      105
# 4       24
#       ...
# 153    118
# 154     13
# 155    136
# 156     21
# 157    141
# Name: Country, Length: 158, dtype: int32

# %%
whr['Region']=pd.DataFrame(le.fit_transform(whr['Region']))
whr['Region']
# Out:
# 0      9
# 1      9
# 2      9
# 3      9
# 4      5
#       ..
# 153    8
# 154    8
# 155    4
# 156    8
# 157    8
# Name: Region, Length: 158, dtype: int32

# %% [markdown]
# # Removing the Outliers and Skewness

# %%
whr.skew()
# Out:
# Country              0.000000
# Region              -0.116119
# Happiness Rank       0.000418
# Happiness Score      0.097769
# Standard Error       1.983439
# Economy             -0.317575
# Family              -1.006893
# Health              -0.705328
# Freedom             -0.413462
# Trust                1.385463
# Generosity           1.001961
# Dystopia Residual   -0.238911
# dtype: float64

# %%
from scipy.stats import zscore
z=np.abs(zscore(whr))
z
# Out:
# array([[1.23877001, 1.30025593, 1.72099989, ..., 2.30965159, 0.47103971,
#         0.75825809],
#        [0.44946522, 1.30025593, 1.69907456, ..., 0.01647953, 1.57585637,
#         1.09285682],
#        [0.90989302, 1.30025593, 1.67714922, ..., 2.8427738 , 0.8242928 ,
#         0.71233526],
#        ...,
#        [1.26069514, 0.37544095, 1.67742676, ..., 0.38141902, 1.85689094,
#         3.20843049],
#        [1.26069514, 0.96511655, 1.69935209, ..., 0.35771452, 0.31694987,
#         0.48198451],
#        [1.37032081, 0.96511655, 1.72127743, ..., 0.30180313, 0.5581534 ,
#         0.96361241]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([ 9,  4,  4,  4, 10,  6,  9, 11,  6], dtype=int64))

# %%
WHR=whr[(z<3).all(axis=1)]
WHR
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0        135       9               1            7.587         0.03411
# 1         58       9               2            7.561         0.04884
# 2         37       9               3            7.527         0.03328
# 3        105       9               4            7.522         0.03880
# 4         24       5               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 150       66       8             151            3.655         0.05141
# 151       20       8             152            3.587         0.04324
# 152        0       7             153            3.575         0.03084
# 154       13       8             155            3.340         0.03656
# 156       21       8             157            2.905         0.08658
#
#      Economy   Family   Health  Freedom    Trust  Generosity  \
# 0    1.39651  1.34951  0.94143  0.66557  0.41978     0.29678
# ...

# %%
print(whr.shape,WHR.shape)
# Out:
# (158, 12) (149, 12)

# %%
for col in WHR.columns:
    if WHR.skew().loc[col]>0.55:
        WHR[col]=np.log1p(WHR[col])

# %%
WHR.skew()
# Out:
# Country              0.048701
# Region              -0.096985
# Happiness Rank       0.003268
# Happiness Score      0.169740
# Standard Error       1.193808
# Economy             -0.390657
# Family              -0.811340
# Health              -0.747711
# Freedom             -0.400867
# Trust                1.095190
# Generosity           0.433539
# Dystopia Residual   -0.021144
# dtype: float64

# %%
WHR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 149 entries, 0 to 156
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            149 non-null    int32
#  1   Region             149 non-null    int32
#  2   Happiness Rank     149 non-null    int64
#  3   Happiness Score    149 non-null    float64
#  4   Standard Error     149 non-null    float64
#  5   Economy            149 non-null    float64
#  6   Family             149 non-null    float64
#  7   Health             149 non-null    float64
#  8   Freedom            149 non-null    float64
#  9   Trust              149 non-null    float64
#  10  Generosity         149 non-null    float64
#  11  Dystopia Residual  149 non-null    float64
# dtypes: float64(9), int32(2), int64(1)
# memory usage: 14.0 KB

# %% [markdown]
# # Spliting the data into input and target

# %%
x=WHR.drop('Happiness Score',axis=1)
x.head()
# Out:
#    Country  Region  Happiness Rank  Standard Error  Economy   Family   Health  \
# 0      135       9               1        0.033541  1.39651  1.34951  0.94143
# 1       58       9               2        0.047685  1.30232  1.40223  0.94784
# 2       37       9               3        0.032738  1.32548  1.36058  0.87464
# 3      105       9               4        0.038066  1.45900  1.33095  0.88521
# 4       24       5               5        0.034913  1.32629  1.32261  0.90563
#
#    Freedom     Trust  Generosity  Dystopia Residual
# 0  0.66557  0.350502    0.259884            2.51738
# 1  0.62877  0.132299    0.362070            2.70201
# 2  0.64938  0.394451    0.293706            2.49204
# 3  0.66973  0.311176    0.297872            2.46531
# 4  0.63297  0.284856    0.377141            2.45176

# %%
y=pd.DataFrame(WHR['Happiness Score'])
y.head()
# Out:
#    Happiness Score
# 0            7.587
# 1            7.561
# 2            7.527
# 3            7.522
# 4            7.427

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
print(x_train.shape,x_test.shape)
# Out:
# (119, 11) (30, 11)

# %%
print(y_train.shape,y_test.shape)
# Out:
# (119, 1) (30, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lg=LinearRegression()
lg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lg.coef_
# Out:
# array([[ 4.97434781e-06, -2.19519233e-04, -3.59858438e-07,
#         -1.31087117e-01,  1.00619990e+00,  1.00200040e+00,
#          1.00295170e+00,  9.86559256e-01,  1.19828229e+00,
#          1.27014547e+00,  9.98417058e-01]])

# %%
lg.intercept_
# Out:
# array([-0.0317245])

# %%
lg.score(x_train,y_train)
# Out:
# 0.9999294053239876

# %%
# to find best fit random state
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=r_state)
    lrg=linear_model.LinearRegression()
    lrg.fit(x_train,y_train)
    y_pred=lrg.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print('r2_score coorsponding to random state is ',r_state,'is:',r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
    
print()
print()
print('Max r2 is cooresponding to ',final_r_state,'is:',max_r_score)
# Out:
# r2_score coorsponding to random state is  42 is: 0.9999617513263428
# r2_score coorsponding to random state is  43 is: 0.9999223558734043
# r2_score coorsponding to random state is  44 is: 0.9999379938683043
# r2_score coorsponding to random state is  45 is: 0.9999389786497637
# r2_score coorsponding to random state is  46 is: 0.9999252551107972
# r2_score coorsponding to random state is  47 is: 0.9999555078199076
# r2_score coorsponding to random state is  48 is: 0.9999026470985282
# r2_score coorsponding to random state is  49 is: 0.9999472066180529
# r2_score coorsponding to random state is  50 is: 0.9998964627314745
# r2_score coorsponding to random state is  51 is: 0.999951394926454
# r2_score coorsponding to random state is  52 is: 0.9999169524783355
# r2_score coorsponding to random state is  53 is: 0.9998679663364899
# r2_score coorsponding to random state is  54 is: 0.9999176837127468
# r2_score coorsponding to random state is  55 is: 0.9998894805387092
# ...

# %%
pred=lg.predict(x_test)
print('Predicted Result Price is ',pred)
print('Actual Price is ',y_test)
# Out:
# Predicted Result Price is  [[3.81373726]
#  [7.26876974]
#  [5.26729187]
#  [4.41613764]
#  [7.42349341]
#  [5.01286343]
#  [5.19532938]
#  [4.69168041]
#  [6.79452446]
#  [5.37515936]
#  [4.33926588]
#  [5.02916338]
#  [4.24945365]
#  [4.89270901]
#  [4.27772068]
#  [6.95164377]
#  [7.28095314]
#  [5.36440984]
#  [5.12965467]
#  [4.68884754]
#  [5.09371969]
#  [5.85534352]
#  [5.96779106]
#  [5.12835017]
#  [4.51892728]
#  [7.37393094]
#  [5.9951143 ]
#  [3.57865712]
#  [5.78021658]
#  [4.71733712]]
# Actual Price is       Happiness Score
# 144            3.819
# 8              7.286
# 77             5.268
# 124            4.419
# 4              7.427
# 92             5.007
# 81             5.192
# 111            4.677
# 24             6.786
# 73             5.399
# 126            4.350
# 90             5.057
# 132            4.252
# 97             4.885
# 129            4.297
# 16             6.946
# 9              7.284
# 74             5.360
# 84             5.129
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=68,test_size=.20)
lrg=linear_model.LinearRegression()
lrg.fit(x_train,y_train)
lrg_pred=lrg.predict(x_test)
print('r2_score is ',r2_score(y_test,lrg_pred))
print('RSME is ',np.sqrt(mean_squared_error(y_test,lrg_pred)))
# Out:
# r2_score is  0.9999718950333549
# RSME is  0.006122773026249619

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=5,scoring='r2')
# Out:
# array([0.99845106, 0.99780362, 0.99742678, 0.99637106, 0.99949896])

# %%
from sklearn.externals import joblib
joblib.dump(lrg,'WHR.pkl')
# Out:
# ['WHR.pkl']
