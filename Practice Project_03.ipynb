# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
aud=pd.read_csv('avacado.csv')
aud
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046       4225  \
# 0              0  27-12-2015          1.33      64236.62   1036.74   54454.85
# 1              1  20-12-2015          1.35      54876.98    674.28   44638.81
# 2              2  13-12-2015          0.93     118220.22    794.70  109149.67
# 3              3  06-12-2015          1.08      78992.15   1132.00   71976.41
# 4              4  29-11-2015          1.28      51039.60    941.48   43838.39
# ...          ...         ...           ...           ...       ...        ...
# 1512          10  16-10-2016          1.39     190846.01  57529.11   56366.66
# 1513          11  09-10-2016          1.51     178235.75  43325.87   52189.61
# 1514          12  02-10-2016          1.48     178410.82  46364.75   52893.38
# 1515          13  25-09-2016          1.47     189131.52  54110.79   53593.58
# 1516          14  18-09-2016          1.43     182978.30  43116.41   54193.42
#
# ...

# %%
# finding shape of the dataset
aud.shape
# Out:
# (1517, 14)

# %%
# finding top 5 values
aud.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1           1  20-12-2015          1.35      54876.98   674.28   44638.81
# 2           2  13-12-2015          0.93     118220.22   794.70  109149.67
# 3           3  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4           4  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
# finding bottom five values 
aud.tail()
# Out:
#       Unnamed: 0        Date  AveragePrice  Total Volume      4046      4225  \
# 1512          10  16-10-2016          1.39     190846.01  57529.11  56366.66
# 1513          11  09-10-2016          1.51     178235.75  43325.87  52189.61
# 1514          12  02-10-2016          1.48     178410.82  46364.75  52893.38
# 1515          13  25-09-2016          1.47     189131.52  54110.79  53593.58
# 1516          14  18-09-2016          1.43     182978.30  43116.41  54193.42
#
#           4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 1512  17531.78    59418.46    48823.53    10354.65       240.28  conventional
# 1513  19419.57    63300.70    54704.14     8596.56         0.00  conventional
# 1514  16736.92    62415.77    53332.61     8258.16       825.00  conventional
# 1515  17495.42    63931.73    55653.47     8278.26         0.00  conventional
# 1516  16563.91    69104.56    57456.21    11648.35         0.00  conventional
#
#       year     region
# ...

# %%
# finding the datatypes of each columns
aud.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
# finding columns present in the dataset
aud.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
# converting the type column and region column into integer format
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
aud['type']=le.fit_transform(aud['type'])
aud['region']=le.fit_transform(aud['region'])

# %%
# drop data column from the data set
aud=aud.drop('Date',axis=1)

# %%
# finding statistical descreption of the data
aud.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %%
# finding null values within the data
aud.isnull().sum()
# Out:
# Unnamed: 0      0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
# it shows that there is no null value present in the data
sns.heatmap(aud.isnull())

# %%
# finding coorelation within the data
sns.heatmap(aud.corr())

# %%
# it shows that there is no coorelation between the type column
aud=aud.drop('type',axis=1)

# %%
sns.heatmap(aud.corr(),annot=True)

# %%
# finding data types of each columns
aud.dtypes
# Out:
# Unnamed: 0        int64
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# year              int64
# region            int32
# dtype: object

# %%
for i in aud.describe().columns:
    sns.boxplot(aud[i].dropna())
    plt.show()

# %% [markdown]
# # finding distribution of skewness

# %%
sns.distplot(aud['AveragePrice'])

# %%
sns.distplot(aud['Total Bags'])

# %%
sns.distplot(aud['Small Bags'])

# %% [markdown]
# # Removing the Skewness From the Data

# %%
aud.skew()
# Out:
# Unnamed: 0     -0.234824
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# region          0.288146
# dtype: float64

# %%
for col in aud.columns:
    if aud.skew().loc[col]>0.55:
        aud[col]=np.log1p(aud[col])

# %%
aud.skew()
# Out:
# Unnamed: 0     -0.234824
# AveragePrice   -0.109444
# Total Volume    0.667468
# 4046           -0.160268
# 4225            0.184436
# 4770           -0.355508
# Total Bags      0.695502
# Small Bags      0.713843
# Large Bags     -0.912766
# XLarge Bags     0.783913
# year            1.828332
# region          0.288146
# dtype: float64

# %%
sns.lineplot(x='Small Bags',y='Total Bags',data=aud)

# %%
sns.lineplot(x='AveragePrice',y='year',data=aud)

# %%
sns.pairplot(aud)

# %% [markdown]
# # Finding and Removing the outliers from the data

# %%
from scipy.stats import zscore
z=np.abs(zscore(aud))
z
# Out:
# array([[1.81868039, 1.35048079, 1.35676174, ..., 0.81077519, 0.44100815,
#         1.3143384 ],
#        [1.75131034, 1.45639674, 1.46638736, ..., 0.81077519, 0.44100815,
#         1.3143384 ],
#        [1.6839403 , 0.76783831, 0.9321394 , ..., 0.81077519, 0.44100815,
#         1.3143384 ],
#        ...,
#        [1.01023983, 2.14485045, 0.64565294, ..., 1.10389091, 2.26753179,
#         0.88028586],
#        [0.94286978, 2.09189247, 0.60503087, ..., 0.81077519, 2.26753179,
#         0.88028586],
#        [0.87549974, 1.88006056, 0.62805557, ..., 0.81077519, 2.26753179,
#         0.88028586]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 760, 1182, 1182, 1182, 1183, 1183, 1183, 1184, 1184, 1184, 1185,
#        1185, 1185, 1186, 1186, 1186, 1187, 1188, 1188, 1188, 1189, 1189,
#        1191, 1202, 1346, 1411, 1457, 1458], dtype=int64), array([1, 2, 6, 7, 2, 6, 7, 2, 6, 7, 2, 6, 7, 2, 6, 7, 7, 2, 6, 7, 2, 6,
#        6, 2, 5, 1, 1, 1], dtype=int64))

# %%
ad=aud[(z<3).all(axis=1)]
ad
# Out:
#       Unnamed: 0  AveragePrice  Total Volume       4046       4225      4770  \
# 0              0          1.33     11.070344   6.944801  10.905146  3.895080
# 1              1          1.35     10.912867   6.515127  10.706381  4.083115
# 2              2          0.93     11.680313   6.679222  11.600485  4.879007
# 3              3          1.08     11.277116   7.032624  11.184108  4.298373
# 4              4          1.28     10.840377   6.848515  10.688288  4.340944
# ...          ...           ...           ...        ...        ...       ...
# 1512          10          1.39     12.159227  10.960064  10.939651  9.771828
# 1513          11          1.51     12.090868  10.676528  10.862658  9.874088
# 1514          12          1.48     12.091850  10.744316  10.876052  9.725432
# 1515          13          1.47     12.150203  10.898807  10.889203  9.769752
# 1516          14          1.43     12.117128  10.671682  10.900333  9.715042
#
# ...

# %%
print(aud.shape, ad.shape)
# Out:
# (1517, 12) (1502, 12)

# %% [markdown]
# # Seprating the input and Output variables from the data

# %%
x=ad.drop(['Total Volume'],axis=1)
x.head()
# Out:
#    Unnamed: 0  AveragePrice      4046       4225      4770  Total Bags  \
# 0           0          1.33  6.944801  10.905146  3.895080    9.070833
# 1           1          1.35  6.515127  10.706381  4.083115    9.159737
# 2           2          0.93  6.679222  11.600485  4.879007    9.005325
# 3           3          1.08  7.032624  11.184108  4.298373    8.667708
# 4           4          1.28  6.848515  10.688288  4.340944    8.729874
#
#    Small Bags  Large Bags  XLarge Bags      year  region
# 0    9.060055    4.545951          0.0  7.608871       0
# 1    9.149429    4.589955          0.0  7.608871       0
# 2    8.992584    4.645736          0.0  7.608871       0
# 3    8.644425    4.903495          0.0  7.608871       0
# 4    8.697389    5.291746          0.0  7.608871       0

# %%
y=ad['Total Volume']
y.head()
# Out:
# 0    11.070344
# 1    10.912867
# 2    11.680313
# 3    11.277116
# 4    10.840377
# Name: Total Volume, dtype: float64

# %%
# To training the model
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (1201, 11) (301, 11)
# (1201,) (301,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_
# Out:
# array([ 2.38046545e-04, -3.46933618e-01,  2.02185049e-01,  3.76002196e-01,
#        -6.20880618e-03,  3.27237418e-01,  5.64223953e-02,  3.97777084e-04,
#        -1.26659564e-02, -1.55762363e+02, -4.78982057e-03])

# %%
lr.intercept_
# Out:
# 1187.675628208507

# %%
lr.score(x_train,y_train)
# Out:
# 0.9808501102205143

# %%
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import cross_val_score
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=r_state)
    lr.fit(x_train,y_train)
    pre=lr.predict(x_test)
    r2_scr=r2_score(y_test,pre)
    print('R2 score is ',r_state,'is',r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
        
print()
print('Max R2 Score is ',final_r_state,'is:',max_r_score)
# Out:
# R2 score is  42 is 0.9770095443832397
# R2 score is  43 is 0.9759089702099398
# R2 score is  44 is 0.9803411549951319
# R2 score is  45 is 0.982167887016249
# R2 score is  46 is 0.978379288971487
# R2 score is  47 is 0.9784742897560263
# R2 score is  48 is 0.9815238175348718
# R2 score is  49 is 0.9763885095533779
# R2 score is  50 is 0.9761859709865849
# R2 score is  51 is 0.9774203992864737
# R2 score is  52 is 0.9810896664917372
# R2 score is  53 is 0.9829085419324675
# R2 score is  54 is 0.9766352714767604
# R2 score is  55 is 0.9813875114481866
# R2 score is  56 is 0.97538320723453
# R2 score is  57 is 0.9813081018299284
# R2 score is  58 is 0.9813811798776241
# R2 score is  59 is 0.9775571254162286
# R2 score is  60 is 0.9834274755208223
# R2 score is  61 is 0.9828272380648063
# R2 score is  62 is 0.9771546931042892
# R2 score is  63 is 0.9798768520334676
# R2 score is  64 is 0.9819049014375651
# R2 score is  65 is 0.9805008344020415
# R2 score is  66 is 0.9790493994917258
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=96)
lr.fit(x_train,y_train)
pre=lr.predict(x_test)
print('r2 score is',r2_score(y_test,pre))
print('RMSE is ',np.sqrt(mean_squared_error(y_test,pre)))
print('Cross Validation Score is ',cross_val_score(LinearRegression(),x,y,cv=5,scoring='r2').mean())
# Out:
# r2 score is 0.9790017917724332
# RMSE is  0.2028413332517335
# Cross Validation Score is  0.9642120729290105

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=96)
rfr.fit(x_train,y_train)
pre=rfr.predict(x_test)
print('r2 score is',r2_score(y_test,pre))
print('RMSE is ',np.sqrt(mean_squared_error(y_test,pre)))
print('Cross Validation Score is ',cross_val_score(RandomForestRegressor(),x,y,cv=5,scoring='r2').mean())
# Out:
# r2 score is 0.9982196323941094
# RMSE is  0.0590636360399389
# Cross Validation Score is  0.9722236919657838

# %%
from sklearn.ensemble import AdaBoostRegressor
abr=AdaBoostRegressor()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=96)
abr.fit(x_train,y_train)
pre=abr.predict(x_test)
print('r2 score is',r2_score(y_test,pre))
print('RMSE is ',np.sqrt(mean_squared_error(y_test,pre)))
print('Cross Validation Score is ',cross_val_score(abr,x,y,cv=5,scoring='r2').mean())
# Out:
# r2 score is 0.9811314985400414
# RMSE is  0.19227996850060997
# Cross Validation Score is  0.9358380172445738

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=96)
gbr.fit(x_train,y_train)
pre=gbr.predict(x_test)
print('r2 score is',r2_score(y_test,pre))
print('RMSE is ',np.sqrt(mean_squared_error(y_test,pre)))
print('Cross Validation Score is ',cross_val_score(abr,x,y,cv=5,scoring='r2').mean())
# Out:
# r2 score is 0.9972055245157403
# RMSE is  0.07399723454207173
# Cross Validation Score is  0.9391524614183734

# %% [markdown]
# # I chose RandomForestClassifier model for making it becauese it show Max r2 score/Cross val score  and very less RMSE

# %%
from sklearn.externals import joblib
joblib.dump(rfr,'Avacado.pkl')
# Out:
# ['Avacado.pkl']
