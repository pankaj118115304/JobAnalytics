# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# finding the total data set
ccd=pd.read_csv('CustCData.csv')
ccd
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# finding the shape of the data
ccd.shape
# Out:
# (7043, 21)

# %%
# finding the each column names of the data
ccd.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# finding the data type of each columns
ccd.dtypes
# it show that lots of data types are object and we need to change them into integer/float
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# Finding the missing values in the data
ccd.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# using label encoder techneque converting the data type of each columns
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ccd.gender=le.fit_transform(ccd.gender)
ccd.Partner=le.fit_transform(ccd.Partner)
ccd.Dependents=le.fit_transform(ccd.Dependents)
ccd.PhoneService=le.fit_transform(ccd.PhoneService)
ccd.MultipleLines=le.fit_transform(ccd.MultipleLines)
ccd.InternetService=le.fit_transform(ccd.InternetService)
ccd.OnlineSecurity=le.fit_transform(ccd.OnlineSecurity)
ccd.OnlineBackup=le.fit_transform(ccd.OnlineBackup)
ccd.DeviceProtection=le.fit_transform(ccd.DeviceProtection)
ccd.TechSupport=le.fit_transform(ccd.TechSupport)
ccd.StreamingTV=le.fit_transform(ccd.StreamingTV)
ccd.StreamingMovies=le.fit_transform(ccd.StreamingMovies)
ccd.Contract=le.fit_transform(ccd.Contract)
ccd.PaperlessBilling=le.fit_transform(ccd.PaperlessBilling)
ccd.PaymentMethod=le.fit_transform(ccd.PaymentMethod)
ccd.TotalCharges=le.fit_transform(ccd.TotalCharges)

# %%
ccd.Churn[ccd.Churn == 'No'] = 0
ccd.Churn[ccd.Churn == 'Yes'] = 1

# %%
ccd['Churn']=ccd['Churn'].astype(int)

# %%
ccd
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG       0              0        1           0       1
# 1     5575-GNVDE       1              0        0           0      34
# 2     3668-QPYBK       1              0        0           0       2
# 3     7795-CFOCW       1              0        0           0      45
# 4     9237-HQITU       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB       1              0        1           1      24
# 7039  2234-XADUH       0              0        1           1      72
# 7040  4801-JZAZL       0              0        1           1      11
# 7041  8361-LTMKD       1              1        1           0       4
# 7042  3186-AJIEK       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
# It shows that there is no missing values present in the data
sns.heatmap(ccd.isnull())

# %%
# finding the statistical description of the data
ccd.describe()
# Out:
#             gender  SeniorCitizen      Partner   Dependents       tenure  \
# count  7043.000000    7043.000000  7043.000000  7043.000000  7043.000000
# mean      0.504756       0.162147     0.483033     0.299588    32.371149
# std       0.500013       0.368612     0.499748     0.458110    24.559481
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       1.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# count   7043.000000    7043.000000      7043.000000     7043.000000
# mean       0.903166       0.940508         0.872923        0.790004
# std        0.295752       0.948554         0.737796        0.859848
# ...

# %%
# finding the coorelation of the data
ccd.corr()
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.001874 -0.001808    0.010517  0.005106
# SeniorCitizen    -0.001874       1.000000  0.016479   -0.211185  0.016567
# Partner          -0.001808       0.016479  1.000000    0.452676  0.379697
# Dependents        0.010517      -0.211185  0.452676    1.000000  0.159712
# tenure            0.005106       0.016567  0.379697    0.159712  1.000000
# PhoneService     -0.006488       0.008576  0.017706   -0.001762  0.008448
# MultipleLines    -0.006739       0.146185  0.142410   -0.024991  0.343032
# InternetService  -0.000863      -0.032310  0.000891    0.044590 -0.030359
# OnlineSecurity   -0.015017      -0.128221  0.150828    0.152166  0.325468
# OnlineBackup     -0.012057      -0.013632  0.153130    0.091015  0.370876
# DeviceProtection  0.000549      -0.021398  0.166330    0.080537  0.371105
# TechSupport      -0.006825      -0.151268  0.126733    0.133524  0.322942
# ...

# %%
sns.heatmap(ccd.corr())

# %%
# finding the outliers within the data
for i in ccd.describe().columns:
    sns.boxplot(ccd[i].dropna())
    plt.show()

# %%
# finding the destribution of skewness within the data
sns.distplot(ccd['tenure'])

# %%
sns.distplot(ccd['OnlineSecurity'])

# %%
sns.distplot(ccd['Churn'])

# %%
sns.distplot(ccd['TotalCharges'])

# %%
for i in ccd.describe().columns:
    plt.hist(ccd[i].dropna())
    plt.show()

# %%
del(ccd['customerID'])

# %%
sns.lineplot(x='MonthlyCharges',y='TotalCharges',data=ccd)

# %%
sns.pairplot(ccd)

# %%
# Removing the skewness and outliers from the data set
ccd.skew()
# Out:
# gender             -0.019031
# SeniorCitizen       1.833633
# Partner             0.067922
# Dependents          0.875199
# tenure              0.239540
# PhoneService       -2.727153
# MultipleLines       0.118719
# InternetService     0.205423
# OnlineSecurity      0.416985
# OnlineBackup        0.182930
# DeviceProtection    0.186847
# TechSupport         0.402365
# StreamingTV         0.028486
# StreamingMovies     0.014657
# Contract            0.630959
# PaperlessBilling   -0.375396
# PaymentMethod      -0.170129
# MonthlyCharges     -0.220524
# TotalCharges        0.015857
# Churn               1.063031
# dtype: float64

# %%
for i in ccd.columns:
    if ccd.skew().loc[i]>0.55:
        ccd[i]=np.log1p(ccd[i])

# %%
from scipy.stats import zscore
z=np.abs(zscore(ccd))
z
# Out:
# array([[1.00955867, 0.43991649, 1.03453023, ..., 1.16032292, 0.39860759,
#         0.60102348],
#        [0.99053183, 0.43991649, 0.96662231, ..., 0.25962894, 0.94876238,
#         0.60102348],
#        [0.99053183, 0.43991649, 0.96662231, ..., 0.36266036, 1.64188328,
#         1.66382851],
#        ...,
#        [1.00955867, 0.43991649, 1.03453023, ..., 1.1686319 , 0.13968008,
#         0.60102348],
#        [0.99053183, 2.27315869, 1.03453023, ..., 0.32033821, 0.31653445,
#         1.66382851],
#        [0.99053183, 0.43991649, 0.96662231, ..., 1.35896134, 1.13801338,
#         0.60102348]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   0,    3,    7,   20,   27,   62,   81,   89,  103,  105,  107,
#         114,  116,  129,  131,  133,  168,  180,  185,  187,  206,  211,
#         215,  216,  217,  225,  236,  252,  255,  259,  260,  263,  272,
#         278,  303,  321,  324,  328,  348,  354,  358,  372,  376,  382,
#         387,  398,  424,  431,  435,  452,  465,  481,  488,  495,  498,
#         544,  569,  596,  610,  616,  620,  634,  660,  667,  669,  674,
#         677,  688,  716,  718,  735,  765,  776,  784,  790,  794,  813,
#         829,  843,  847,  859,  866,  873,  875,  877,  884,  893,  917,
#         934,  941,  943,  960,  973, 1011, 1018, 1037, 1050, 1051, 1053,
#        1072, 1110, 1119, 1122, 1144, 1146, 1150, 1161, 1169, 1182, 1204,
#        1221, 1225, 1242, 1255, 1257, 1271, 1278, 1298, 1311, 1326, 1331,
#        1333, 1334, 1340, 1349, 1352, 1365, 1379, 1402, 1407, 1416, 1452,
#        1479, 1480, 1481, 1500, 1506, 1513, 1519, 1560, 1562, 1581, 1584,
# ...

# %%
cc=ccd[(z<3).all(axis=1)]
cc
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 4          0              0        0           0       2             1
# 5          0              0        0           0       8             1
# 6          1              0        0           1      22             1
# ...      ...            ...      ...         ...     ...           ...
# 7037       0              0        0           0      72             1
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
# finding the shape of old and new data set
print(ccd.shape , cc.shape)
# Out:
# (7043, 20) (6361, 20)

# %% [markdown]
# # seprating the inputs and outputs variables from the data set

# %%
x=ccd.iloc[:,0:-1]
x.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
y=ccd.iloc[:,-1]
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int32

# %%
# Training the model withh x train , y train
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)
print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (5634, 19) (1409, 19)
# (5634,) (1409,)

# %%
# Fitting the model
from sklearn.linear_model import LogisticRegression
lgr=LogisticRegression()
lgr.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
ccd
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
# Fitting the model
from sklearn.linear_model import LogisticRegression
lgr=LogisticRegression()
lgr.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score,GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,auc

# %%
lgr=LogisticRegression()
dtc=DecisionTreeClassifier()
knn=KNeighborsClassifier()
sv=SVC()
rfc=RandomForestClassifier()
abc=AdaBoostClassifier()
gbc=GradientBoostingClassifier()
models=[]
models.append(('LogisticRegression',lgr))
models.append(('DecisionTreeClassifier',dtc))
models.append(('KNeighborsClassifier',knn))
models.append(('SVC',sv))
models.append(('RandomForestClassifier',rfc))
models.append(('AdaBoostClassifier',abc))
models.append(('GradientBoostingClassifier',gbc))

# %%
Model=[]
score=[]
cvs=[]
rocscore=[]
for i,model in models:
    print('******************',i,'*******************','\n')
    Model.append(i)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    AS=accuracy_score(y_test,pre)
    print('Accuracy Score is ',AS,'\n')
    score.append(AS*100)
    CM=confusion_matrix(y_test,pre)
    print('Confusion Matrix is \n',CM,'\n')
    print('Classification Report is',classification_report(y_test,pre),'\n')
    cs=cross_val_score(model,x,y,cv=5,scoring='accuracy').mean()
    print('Cross Validation Score is ',cs,'\n')
    cvs.append(cs*100)
    fpr,tpr,threshold=roc_curve(y_test,pre)
    auc_roc=auc(fpr,tpr)
    print('Auc Roc Score is ',auc_roc,'\n')
    rocscore.append(auc_roc*100)
# Out:
# ****************** LogisticRegression *******************
#
# Accuracy Score is  0.8133427963094393
#
# Confusion Matrix is
#  [[935 101]
#  [162 211]]
#
# Classification Report is               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88      1036
#            1       0.68      0.57      0.62       373
#
#     accuracy                           0.81      1409
#    macro avg       0.76      0.73      0.75      1409
# weighted avg       0.81      0.81      0.81      1409
#
#
# Cross Validation Score is  0.7993762702432415
#
# Auc Roc Score is  0.7340966493111266
#
# ****************** DecisionTreeClassifier *******************
#
# Accuracy Score is  0.7239176721078779
#
# Confusion Matrix is
#  [[853 183]
#  [206 167]]
#
# Classification Report is               precision    recall  f1-score   support
#
#            0       0.81      0.82      0.81      1036
#            1       0.48      0.45      0.46       373
#
# ...

# %%
result=pd.DataFrame({'Model':Model,'Accuracy Score':score,'CVS':cvs,'AUC ROC Score':rocscore})
result
# Out:
#                         Model  Accuracy Score        CVS  AUC ROC Score
# 0          LogisticRegression       81.334280  79.937627      73.409665
# 1      DecisionTreeClassifier       72.391767  72.681877      63.554013
# 2        KNeighborsClassifier       75.656494  74.740840      64.744661
# 3                         SVC       73.527324  73.463016      50.000000
# 4      RandomForestClassifier       79.418027  79.028970      68.760933
# 5          AdaBoostClassifier       80.553584  80.249925      72.535634
# 6  GradientBoostingClassifier       81.121363  80.363471      72.149663

# %%
from sklearn.externals import joblib
joblib.dump(lgr,'CustChurndata.pkl')
# Out:
# ['CustChurndata.pkl']
