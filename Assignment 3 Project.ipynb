# %% [raw]
# Perform proper data cleaning
# - Focus on data visualization and infer details from it.
# - Use 4-5 models for training, do proper hyperparameter tuning and choose the right evaluation metrics to finalize your model.
# - Create a detailed report mentioning all the steps in the format of sample documentation file.
# - Create a powerpoint presentation of the project.
# - Test your predictions on multiple metrics like ROC-AUC curve, accuracy, Recall and Precision.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# finding the micro cradit data from the file 
micro=pd.read_csv("Data file.csv",parse_dates=['pdate'])
micro
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
# finding the top 10 data values
micro.head(10)
# Out:
#    Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789   272.0   3055.050000   3065.150000
# 1           2      1  76462I70374   712.0  12122.000000  12124.750000
# 2           3      1  17943I70372   535.0   1398.000000   1398.000000
# 3           4      1  55773I70781   241.0     21.228000     21.228000
# 4           5      1  03813I82730   947.0    150.619333    150.619333
# 5           6      1  35819I70783   568.0   2257.362667   2261.460000
# 6           7      1  96759I84459   545.0   2876.641667   2883.970000
# 7           8      1  09832I90846   768.0  12905.000000  17804.150000
# 8           9      1  59772I84450  1191.0     90.695000     90.695000
# 9          10      1  56331I70783   536.0     29.357333     29.357333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# ...

# %%
# finding the bottom 10 data values
micro.tail(10)
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 209583      209584      1  30201I82732   935.0     15.550667     15.550667
# 209584      209585      0  70387I89237   945.0      0.000000      0.000000
# 209585      209586      1  12227I90843   793.0   5350.315333   5356.210000
# 209586      209587      1  60331I70370   254.0  20079.157333  20228.090000
# 209587      209588      1  19900I95200   239.0  14678.000000  14704.900000
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 209583    140.44    140.44                4.0                0.0  ...
# ...

# %%
#finding the data type of each columns
micro.dtypes
# Out:
# Unnamed: 0                       int64
# label                            int64
# msisdn                          object
# aon                            float64
# daily_decr30                   float64
# daily_decr90                   float64
# rental30                       float64
# rental90                       float64
# last_rech_date_ma              float64
# last_rech_date_da              float64
# last_rech_amt_ma                 int64
# cnt_ma_rech30                    int64
# fr_ma_rech30                   float64
# sumamnt_ma_rech30              float64
# medianamnt_ma_rech30           float64
# medianmarechprebal30           float64
# cnt_ma_rech90                    int64
# fr_ma_rech90                     int64
# sumamnt_ma_rech90                int64
# medianamnt_ma_rech90           float64
# medianmarechprebal90           float64
# cnt_da_rech30                  float64
# fr_da_rech30                   float64
# cnt_da_rech90                    int64
# ...

# %%
# finding the shape of the data 
micro.shape
# Out:
# (209593, 37)

# %%
# finding the column's names present in the data set
micro.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
# it shows that there is ni null values present in the data set
micro.isnull().sum()
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %%
# finding the total loan paid/default list
micro['label'].value_counts() # it shows that more no of loans are default i.e 26162
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %%
# finding the number of loans taken by the users in last 30 days
micro['cnt_loans30'].value_counts()
# Out:
# 1     83432
# 2     42665
# 3     27050
# 4     17499
# 5     11673
# 6      7773
# 7      5041
# 8      3384
# 0      3259
# 9      2273
# 10     1571
# 11     1143
# 12      793
# 13      547
# 14      383
# 15      270
# 16      213
# 17      164
# 18       98
# 19       77
# 20       54
# 21       45
# 22       42
# 23       38
# 25       19
# 26       17
# 27       15
# 24       13
# 29        9
# 31        8
# 28        7
# 30        4
# 32        4
# 33        3
# 38        2
# 41        1
# 44        1
# 36        1
# 35        1
# 50        1
# Name: cnt_loans30, dtype: int64

# %%
# finding the amount of loans taken by the users in last 30 days
micro['maxamnt_loans30'].value_counts()
# Out:
# 6.000000        179193
# 12.000000        26109
# 0.000000          3244
# 59275.166722         1
# 68599.755670         1
#                  ...
# 26462.333521         1
# 53666.885900         1
# 67319.013426         1
# 36610.121211         1
# 28708.879352         1
# Name: maxamnt_loans30, Length: 1050, dtype: int64

# %%
# from pdate we can get the monthly,yearly and daily loan cases
cds_dates=pd.DataFrame()
cds_dates['Month']=micro['pdate'].dt.month_name()
cds_dates['Year']=micro['pdate'].dt.year
cds_dates['Day']=micro['pdate'].dt.day_name()
cds_dates
# Out:
#          Month  Year        Day
# 0         July  2016  Wednesday
# 1       August  2016  Wednesday
# 2       August  2016     Friday
# 3         June  2016     Monday
# 4         June  2016  Wednesday
# ...        ...   ...        ...
# 209588    June  2016     Friday
# 209589    June  2016     Sunday
# 209590    July  2016     Friday
# 209591    July  2016     Monday
# 209592    July  2016   Thursday
#
# [209593 rows x 3 columns]

# %%
MCD=pd.concat([micro,cds_dates],axis=1)
MCD
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
# droping the pdate and unnamed ,year,mobile nos columns from the data set
del(MCD['pdate'])
del(MCD['Unnamed: 0'])
del(MCD['Year'])
del(MCD['msisdn'])

# %%
# finding the total dataset
MCD.head(10)
# Out:
#    label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0   272.0   3055.050000   3065.150000    220.13    260.13
# 1      1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1   535.0   1398.000000   1398.000000    900.13    900.13
# 3      1   241.0     21.228000     21.228000    159.42    159.42
# 4      1   947.0    150.619333    150.619333   1098.90   1098.90
# 5      1   568.0   2257.362667   2261.460000    368.13    380.13
# 6      1   545.0   2876.641667   2883.970000    335.75    402.90
# 7      1   768.0  12905.000000  17804.150000    900.35   2549.11
# 8      1  1191.0     90.695000     90.695000   2287.50   2287.50
# 9      1   536.0     29.357333     29.357333    612.96    612.96
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  ...  \
# 0                2.0                0.0              1539              2  ...
# 1               20.0                0.0              5787              1  ...
# ...

# %%
# finding the month wise loans users
MCD['Month'].value_counts()
# Out:
# July      85765
# June      83154
# August    40674
# Name: Month, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
# let changing the object data type into integer
MCD['pcircle']=le.fit_transform(MCD['pcircle'])
MCD['Month']=le.fit_transform(MCD['Month'])
MCD['Day']=le.fit_transform(MCD['Day'])

# %%
# now we have all the data in integer and float format
MCD.head(10)
# Out:
#    label     aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0   272.0   3055.050000   3065.150000    220.13    260.13
# 1      1   712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1   535.0   1398.000000   1398.000000    900.13    900.13
# 3      1   241.0     21.228000     21.228000    159.42    159.42
# 4      1   947.0    150.619333    150.619333   1098.90   1098.90
# 5      1   568.0   2257.362667   2261.460000    368.13    380.13
# 6      1   545.0   2876.641667   2883.970000    335.75    402.90
# 7      1   768.0  12905.000000  17804.150000    900.35   2549.11
# 8      1  1191.0     90.695000     90.695000   2287.50   2287.50
# 9      1   536.0     29.357333     29.357333    612.96    612.96
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  ...  \
# 0                2.0                0.0              1539              2  ...
# 1               20.0                0.0              5787              1  ...
# ...

# %%
# finding the statistical description of the data
MCD.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %%
# finding the cooreletion of the data
MCD.corr()
# Out:
#                          label       aon  daily_decr30  daily_decr90  \
# label                 1.000000 -0.003785      0.168298      0.166150
# aon                  -0.003785  1.000000      0.001104      0.000374
# daily_decr30          0.168298  0.001104      1.000000      0.977704
# daily_decr90          0.166150  0.000374      0.977704      1.000000
# rental30              0.058085 -0.000960      0.442066      0.434685
# rental90              0.075521 -0.000790      0.458977      0.471730
# last_rech_date_ma     0.003728  0.001692      0.000487      0.000908
# last_rech_date_da     0.001711 -0.001693     -0.001636     -0.001886
# last_rech_amt_ma      0.131804  0.004256      0.275837      0.264131
# cnt_ma_rech30         0.237331 -0.003148      0.451385      0.426707
# fr_ma_rech30          0.001330 -0.001163     -0.000577     -0.000343
# sumamnt_ma_rech30     0.202828  0.000707      0.636536      0.603886
# medianamnt_ma_rech30  0.141490  0.004306      0.295356      0.282960
# ...

# %%
# analysing the cooreletion with the use of heatmap
sns.heatmap(MCD.corr())

# %%
# finding the null values present in the data through graphing
print(MCD.isnull().sum()) ,'\n'
print(sns.heatmap(MCD.isnull())) # it shows that there is no null values are present in the data set
# Out:
# label                   0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# Month                   0
# ...

# %% [markdown]
# # using univariate and bivariate analysis

# %%
# finding the outliers within the data set
for i in MCD.describe().columns:
    sns.boxplot(MCD[i].dropna())
    plt.show() # it shows that there are some outliers present in the data

# %%
for i in MCD.describe().columns:
    plt.hist(MCD[i].dropna())
    plt.show()

# %% [markdown]
# # finding the distribution of skewness within the data

# %%
sns.distplot(MCD['cnt_loans30'])

# %%
sns.distplot(MCD['rental30'])

# %%
sns.distplot(MCD['rental90'])

# %%
sns.lineplot(y='label',x='maxamnt_loans30',data=MCD)

# %%
sns.lineplot(x='amnt_loans30',y='label',data=MCD)

# %%
sns.lineplot(x='cnt_loans30',y='label',data=MCD)

# %%
sns.lineplot(x='last_rech_amt_ma',y='label',data=MCD)

# %%
# finding the skewness within the data set
MCD.skew()
# Out:
# label                   -2.270254
# aon                     10.392949
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_date_ma       14.790974
# last_rech_date_da       14.814857
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779875
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# fr_da_rech30            14.776430
# cnt_da_rech90           27.267278
# fr_da_rech90            28.988083
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# maxamnt_loans30         17.658052
# medianamnt_loans30       4.551043
# ...

# %% [markdown]
# # Removing the skewness and outliers from the data

# %%
from scipy.stats import zscore
z=np.abs(zscore(MCD))
z
# Out:
# array([[2.64789583, 0.10357685, 0.25229941, ...,        nan, 0.27336037,
#         1.48870216],
#        [0.37765836, 0.09776412, 0.73103667, ...,        nan, 1.62209905,
#         1.48870216],
#        [0.37765836, 0.10010243, 0.43201111, ...,        nan, 1.62209905,
#         1.49224832],
#        ...,
#        [0.37765836, 0.09378769, 0.70079045, ...,        nan, 0.27336037,
#         1.49224832],
#        [0.37765836, 0.08428915, 0.77075515, ...,        nan, 0.27336037,
#         0.99542324],
#        [0.37765836, 0.08628398, 0.09674426, ...,        nan, 0.27336037,
#         0.495052  ]])

# %%
thresolds=3
print(np.where(z>3))
# Out:
# (array([    21,     22,     22, ..., 209586, 209587, 209587], dtype=int64), array([15, 15, 32, ..., 28, 26, 30], dtype=int64))

# %%
mcd=MCD[(z<3).all(axis=1)]
mcd
# Out:
# Empty DataFrame
# Columns: [label, aon, daily_decr30, daily_decr90, rental30, rental90, last_rech_date_ma, last_rech_date_da, last_rech_amt_ma, cnt_ma_rech30, fr_ma_rech30, sumamnt_ma_rech30, medianamnt_ma_rech30, medianmarechprebal30, cnt_ma_rech90, fr_ma_rech90, sumamnt_ma_rech90, medianamnt_ma_rech90, medianmarechprebal90, cnt_da_rech30, fr_da_rech30, cnt_da_rech90, fr_da_rech90, cnt_loans30, amnt_loans30, maxamnt_loans30, medianamnt_loans30, cnt_loans90, amnt_loans90, maxamnt_loans90, medianamnt_loans90, payback30, payback90, pcircle, Month, Day]
# Index: []
#
# [0 rows x 36 columns]

# %% [markdown]
# # Seperating the x and y variable from the micro credit defaulter data

# %%
x=MCD.drop('label',axis=1)
x.head()
# Out:
#      aon  daily_decr30  daily_decr90  rental30  rental90  last_rech_date_ma  \
# 0  272.0   3055.050000   3065.150000    220.13    260.13                2.0
# 1  712.0  12122.000000  12124.750000   3691.26   3691.26               20.0
# 2  535.0   1398.000000   1398.000000    900.13    900.13                3.0
# 3  241.0     21.228000     21.228000    159.42    159.42               41.0
# 4  947.0    150.619333    150.619333   1098.90   1098.90                4.0
#
#    last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  ...  \
# 0                0.0              1539              2          21.0  ...
# 1                0.0              5787              1           0.0  ...
# 2                0.0              1539              1           0.0  ...
# 3                0.0               947              0           0.0  ...
# 4                0.0              2309              7           2.0  ...
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# ...

# %%
y=MCD['label']
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# Name: label, dtype: int64

# %%
# train and test the model  
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (167674, 35) (41919, 35)
# (167674,) (41919,)

# %%
# importing the necessary classifiers to predict the model
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score,GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,auc

# %%
lgr=LogisticRegression()
dtc=DecisionTreeClassifier()
knn=KNeighborsClassifier()
sv=SVC()
rfc=RandomForestClassifier()
abc=AdaBoostClassifier()
gbc=GradientBoostingClassifier()
models=[]
models.append(('LogisticRegression',lgr))
models.append(('DecisionTreeClassifier',dtc))
models.append(('KNeighborsClassifier',knn))
models.append(('SVC',sv))
models.append(('RandomForestClassifier',rfc))
models.append(('AdaBoostClassifier',abc))
models.append(('GradientBoostingClassifier',gbc))

# %%
Model=[]
score=[]
cvs=[]
rocscore=[]
for i,model in models:
    print('******************',i,'*******************','\n')
    Model.append(i)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    AS=accuracy_score(y_test,pre)
    print('Accuracy Score is ',AS,'\n')
    score.append(AS*100)
    CM=confusion_matrix(y_test,pre)
    print('Confusion Matrix is \n',CM,'\n')
    print('Classification Report is',classification_report(y_test,pre),'\n')
    cs=cross_val_score(model,x,y,cv=5,scoring='accuracy').mean()
    print('Cross Validation Score is ',cs,'\n')
    cvs.append(cs*100)
    fpr,tpr,thresholds=roc_curve(y_test,pre)
    roc_auc=auc(fpr,tpr)
    print('Roc Auc Score is',roc_auc,'\n')
    rocscore.append(roc_auc*100)
# Out:
# ****************** LogisticRegression *******************
#
# Accuracy Score is  0.8680073475035187
#
# Confusion Matrix is
#  [[ 1034  4263]
#  [ 1270 35352]]
#
# Classification Report is               precision    recall  f1-score   support
#
#            0       0.45      0.20      0.27      5297
#            1       0.89      0.97      0.93     36622
#
#     accuracy                           0.87     41919
#    macro avg       0.67      0.58      0.60     41919
# weighted avg       0.84      0.87      0.84     41919
#
#
# Cross Validation Score is  0.8690843744723482
#
# Roc Auc Score is 0.5802631122187974
#
# ****************** DecisionTreeClassifier *******************
#
# Accuracy Score is  0.8698680789140962
#
# Confusion Matrix is
#  [[ 2760  2537]
#  [ 2918 33704]]
#
# Classification Report is               precision    recall  f1-score   support
#
#            0       0.49      0.52      0.50      5297
#            1       0.93      0.92      0.93     36622
#
# ...

# %%
result=pd.DataFrame({'Model':Model,'Accuracy Score':score,'CVS':cvs,'Roc Auc Score':rocscore})
result
