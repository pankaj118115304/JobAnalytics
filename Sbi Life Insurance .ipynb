# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
sli=pd.read_csv('Sbi_Life_Insurance.csv')
sli
# Out:
#       age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0      19    0  27.900         0       1       3  16884.92400               1
# 1      18    1  33.770         1       0       2   1725.55230               1
# 2      28    1  33.000         3       0       2   4449.46200               0
# 3      33    1  22.705         0       0       1  21984.47061               0
# 4      32    1  28.880         0       0       1   3866.85520               1
# ...   ...  ...     ...       ...     ...     ...          ...             ...
# 1333   50    1  30.970         3       0       1  10600.54830               0
# 1334   18    0  31.920         0       0       0   2205.98080               1
# 1335   18    0  36.850         0       0       2   1629.83350               1
# 1336   21    0  25.800         0       0       3   2007.94500               0
# 1337   61    0  29.070         0       1       1  29141.36030               1
#
# [1338 rows x 8 columns]

# %%
# finding top 5 data
sli.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0   19    0  27.900         0       1       3  16884.92400               1
# 1   18    1  33.770         1       0       2   1725.55230               1
# 2   28    1  33.000         3       0       2   4449.46200               0
# 3   33    1  22.705         0       0       1  21984.47061               0
# 4   32    1  28.880         0       0       1   3866.85520               1

# %%
# finding bottom 5 data
sli.tail()
# Out:
#       age  sex    bmi  children  smoker  region     charges  insuranceclaim
# 1333   50    1  30.97         3       0       1  10600.5483               0
# 1334   18    0  31.92         0       0       0   2205.9808               1
# 1335   18    0  36.85         0       0       2   1629.8335               1
# 1336   21    0  25.80         0       0       3   2007.9450               0
# 1337   61    0  29.07         0       1       1  29141.3603               1

# %%
# finding shape of the data
sli.shape
# Out:
# (1338, 8)

# %%
# finding missing values
sli.isnull().sum()
# Out:
# age               0
# sex               0
# bmi               0
# children          0
# smoker            0
# region            0
# charges           0
# insuranceclaim    0
# dtype: int64

# %%
# finding missing values with heatmap method
sns.heatmap(sli.isnull())
# it is showing that there is no missing values in the data

# %%
# finding 
sli.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             1338 non-null   int64
#  1   sex             1338 non-null   int64
#  2   bmi             1338 non-null   float64
#  3   children        1338 non-null   int64
#  4   smoker          1338 non-null   int64
#  5   region          1338 non-null   int64
#  6   charges         1338 non-null   float64
#  7   insuranceclaim  1338 non-null   int64
# dtypes: float64(2), int64(6)
# memory usage: 83.8 KB

# %%
# Finding Statistical Discreption of data
sli.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges  insuranceclaim
# count  1338.000000   1338.000000     1338.000000
# mean      1.515695  13270.422265        0.585202
# std       1.104885  12110.011237        0.492871
# min       0.000000   1121.873900        0.000000
# 25%       1.000000   4740.287150        0.000000
# ...

# %%
# Finding Coorelation of Data
sli.corr()
# Out:
#                      age       sex       bmi  children    smoker    region  \
# age             1.000000 -0.020856  0.109272  0.042469 -0.025019  0.002127
# sex            -0.020856  1.000000  0.046371  0.017163  0.076185  0.004588
# bmi             0.109272  0.046371  1.000000  0.012759  0.003750  0.157566
# children        0.042469  0.017163  0.012759  1.000000  0.007673  0.016569
# smoker         -0.025019  0.076185  0.003750  0.007673  1.000000 -0.002181
# region          0.002127  0.004588  0.157566  0.016569 -0.002181  1.000000
# charges         0.299008  0.057292  0.198341  0.067998  0.787251 -0.006208
# insuranceclaim  0.113723  0.031565  0.384198 -0.409526  0.333261  0.020891
#
#                  charges  insuranceclaim
# age             0.299008        0.113723
# sex             0.057292        0.031565
# bmi             0.198341        0.384198
# children        0.067998       -0.409526
# smoker          0.787251        0.333261
# region         -0.006208        0.020891
# ...

# %%
# Finding Correlation using heatmap
sns.heatmap(sli.corr())

# %% [markdown]
# # Univariate and Bivariate Analaysis

# %%
plt.boxplot(sli['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bbc1d04fc8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2bbc1d05b08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2bbc1cf0348>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bbc1d05e88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bbc1d08b48>],
#  'means': []}

# %%
plt.boxplot(sli['bmi'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bbc1d1a688>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2bbc1d27cc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2bbc1d10788>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bbc1d2afc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bbc1d2aec8>],
#  'means': []}

# %%
plt.boxplot(sli['region'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bbc1d51b88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2bbc1d51f08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2bbc1d36488>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bbc1d53a48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bbc1d53f88>],
#  'means': []}

# %%
sli.plot(kind='box',subplots=True,layout=(1,8))
# Out:
# age                  AxesSubplot(0.125,0.125;0.0824468x0.755)
# sex               AxesSubplot(0.223936,0.125;0.0824468x0.755)
# bmi               AxesSubplot(0.322872,0.125;0.0824468x0.755)
# children          AxesSubplot(0.421809,0.125;0.0824468x0.755)
# smoker            AxesSubplot(0.520745,0.125;0.0824468x0.755)
# region            AxesSubplot(0.619681,0.125;0.0824468x0.755)
# charges           AxesSubplot(0.718617,0.125;0.0824468x0.755)
# insuranceclaim    AxesSubplot(0.817553,0.125;0.0824468x0.755)
# dtype: object

# %%
plt.hist(sli)
plt.xlabel('age')
plt.ylabel('insuranceclaim')
plt.show()

# %%
sns.barplot(x='sex',y='insuranceclaim',data=sli)

# %%
sns.lineplot(x='smoker',y='insuranceclaim',data=sli)

# %%
sns.distplot(sli['region'])

# %%
for i in sli.describe().columns:
    sns.boxplot(sli[i].dropna())
    plt.show()

# %%
sns.pairplot(sli)

# %% [markdown]
# # Removing the outliers and skewness from the data

# %%
sli.skew()
# Out:
# age               0.055673
# sex              -0.020951
# bmi               0.284047
# children          0.938380
# smoker            1.464766
# region           -0.038101
# charges           1.515880
# insuranceclaim   -0.346254
# dtype: float64

# %%
from scipy.stats import zscore
z=np.abs(zscore(sli))
z
# Out:
# array([[1.43876426, 1.0105187 , 0.45332   , ..., 1.34390459, 0.2985838 ,
#         0.84190989],
#        [1.50996545, 0.98959079, 0.5096211 , ..., 0.43849455, 0.95368917,
#         0.84190989],
#        [0.79795355, 0.98959079, 0.38330685, ..., 0.43849455, 0.72867467,
#         1.18777557],
#        ...,
#        [1.50996545, 1.0105187 , 1.0148781 , ..., 0.43849455, 0.96159623,
#         0.84190989],
#        [1.29636188, 1.0105187 , 0.79781341, ..., 1.34390459, 0.93036151,
#         1.18777557],
#        [1.55168573, 1.0105187 , 0.26138796, ..., 0.46691549, 1.31105347,
#         0.84190989]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  32,   34,   71,  116,  166,  413,  425,  438,  543,  568,  577,
#         640,  819,  847,  877,  932,  937,  969,  984, 1047, 1085, 1116,
#        1130, 1146, 1230, 1245, 1272, 1300, 1317], dtype=int64), array([3, 6, 3, 2, 3, 3, 3, 3, 6, 3, 6, 3, 6, 2, 3, 3, 3, 3, 3, 2, 3, 3,
#        3, 6, 6, 3, 3, 6, 2], dtype=int64))

# %%
sbi=sli[(z<3).all(axis=1)]
sbi
# Out:
#       age  sex     bmi  children  smoker  region      charges  insuranceclaim
# 0      19    0  27.900         0       1       3  16884.92400               1
# 1      18    1  33.770         1       0       2   1725.55230               1
# 2      28    1  33.000         3       0       2   4449.46200               0
# 3      33    1  22.705         0       0       1  21984.47061               0
# 4      32    1  28.880         0       0       1   3866.85520               1
# ...   ...  ...     ...       ...     ...     ...          ...             ...
# 1333   50    1  30.970         3       0       1  10600.54830               0
# 1334   18    0  31.920         0       0       0   2205.98080               1
# 1335   18    0  36.850         0       0       2   1629.83350               1
# 1336   21    0  25.800         0       0       3   2007.94500               0
# 1337   61    0  29.070         0       1       1  29141.36030               1
#
# [1309 rows x 8 columns]

# %%
print(sli.shape,sbi.shape)
# Out:
# (1338, 8) (1309, 8)

# %%
for col in sbi.columns:
    if sbi.skew().loc[col]>0.55:
        sbi[col]=np.log1p(sbi[col])

# %%
sbi.skew()
# Out:
# age               0.051340
# sex              -0.010708
# bmi               0.191432
# children          0.225539
# smoker            1.482731
# region           -0.023027
# charges          -0.107087
# insuranceclaim   -0.352569
# dtype: float64

# %% [markdown]
# # Seprating input and output variables from the data

# %%
x=sbi.iloc[:,0:-1]
x.head()
# Out:
#    age  sex     bmi  children    smoker  region   charges
# 0   19    0  27.900  0.000000  0.693147       3  9.734236
# 1   18    1  33.770  0.693147  0.000000       2  7.453882
# 2   28    1  33.000  1.386294  0.000000       2  8.400763
# 3   33    1  22.705  0.000000  0.000000       1  9.998137
# 4   32    1  28.880  0.000000  0.000000       1  8.260455

# %%
y=sbi.iloc[:,-1]
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    1
# Name: insuranceclaim, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)
print(x_train.shape,x_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (1047, 7) (262, 7)
# (1047,) (262,)

# %%
from sklearn.linear_model import LogisticRegression
lgr=LogisticRegression()
lgr.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# Finalazing the model
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,auc
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.svm import SVC

# %%
KNN=KNeighborsClassifier()
SV=SVC()
LR=LogisticRegression()
DTC=DecisionTreeClassifier()
GBC=GradientBoostingClassifier()
ABC=AdaBoostClassifier()
RFC=RandomForestClassifier()
models=[]
models.append(('KNeighborsClassifier',KNN))
models.append(('SVC',SV))
models.append(('LogisticRegression',LR))
models.append(('DecisionTreeClassifier',DTC))
models.append(('GradientBoostingClassifier',GBC))
models.append(('AdaBoostClassifier',ABC))
models.append(('RandomForestClassifier',RFC))

# %%
Model=[]
score=[]
cvs  =[]
rocscore=[]
for i,model in models:
    print('***************',i,'***************','\n')
    Model.append(i)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    AS=accuracy_score(y_test,pre)
    print('Accuracy Score is ',AS)
    score.append(AS*100)
    CM=confusion_matrix(y_test,pre)
    print('Confusion Matrix is \n',CM,'\n')
    print('Classification Report is \n',classification_report(y_test,pre),'\n')
    cs=cross_val_score(model,x,y,cv=5,scoring='accuracy').mean()
    print('Cross Validation Score is',cs,'\n')
    cvs.append(cs*100)
    fpr,tpr,thresholds=roc_curve(y_test,pre)
    roc_auc=auc(fpr,tpr)
    print('Roc Auc Score is ',roc_auc,'\n')
    rocscore.append(roc_auc*100)
# Out:
# *************** KNeighborsClassifier ***************
#
# Accuracy Score is  0.7786259541984732
# Confusion Matrix is
#  [[ 79  20]
#  [ 38 125]]
#
# Classification Report is
#                precision    recall  f1-score   support
#
#            0       0.68      0.80      0.73        99
#            1       0.86      0.77      0.81       163
#
#     accuracy                           0.78       262
#    macro avg       0.77      0.78      0.77       262
# weighted avg       0.79      0.78      0.78       262
#
#
# Cross Validation Score is 0.765479219677693
#
# Roc Auc Score is  0.7824254818119849
#
# *************** SVC ***************
#
# Accuracy Score is  0.7519083969465649
# Confusion Matrix is
#  [[ 62  37]
#  [ 28 135]]
#
# Classification Report is
#                precision    recall  f1-score   support
#
#            0       0.69      0.63      0.66        99
#            1       0.78      0.83      0.81       163
#
#     accuracy                           0.75       262
# ...

# %%
result=pd.DataFrame({'Model':Model,'Accuracy Score':score,'Cross Val Score':cvs,'Roc Auc Score':rocscore})
result
# Out:
#                         Model  Accuracy Score  Cross Val Score  Roc Auc Score
# 0        KNeighborsClassifier       77.862595        76.547922      78.242548
# 1                         SVC       75.190840        72.498026      72.724174
# 2          LogisticRegression       87.022901        87.012372      86.397720
# 3      DecisionTreeClassifier       98.854962        97.325904      98.881453
# 4  GradientBoostingClassifier       96.946565        97.096897      97.347710
# 5          AdaBoostClassifier       85.877863        85.485654      85.279172
# 6      RandomForestClassifier       94.656489        95.110117      95.308917

# %% [markdown]
# i Choose DecisionTreeClassifier for making the model as it is perform very well on my dataset
#
# Accuracy Score = 98.854962 ,
# Cross Val Score= 97.861133 ,
# Roc Auc Score  = 98.881453

# %%
dtc=DecisionTreeClassifier()
grid_param={
    'criterion': ['gini','entropy']
    }

gd_sr=GridSearchCV(estimator=dtc,
                  param_grid=grid_param,
                  scoring='accuracy',
                  cv=5)

gd_sr.fit(x,y)
best_parameters=gd_sr.best_params_
print(best_parameters)
best_result=gd_sr.best_score_
print(best_result)
# Out:
# {'criterion': 'entropy'}
# 0.9793746892457079

# %%
from sklearn.externals import joblib
joblib.dump(DTC,'Sbi_Life_Insurance.pkl')
# Out:
# ['Sbi_Life_Insurance.pkl']
