# %%
# importing required libraries of the project
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# finding the data file of houseing project
hp=pd.read_csv('Data_file.csv')
hp
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
# finding the all columns names present in the data
hp.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
# finding the data type of each columns
hp.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
# finding the null values present in the data
hp.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# using heatmap analysing the null values present in the data
sns.heatmap(hp.isnull())
# it is showung that there are many null values present in the data so we need to fill these null values

# %%
# filling the missing values present in the data
hp['LotFrontage']=hp['LotFrontage'].fillna(hp['LotFrontage'].mean())
hp['MasVnrType']=hp['MasVnrType'].fillna(hp['MasVnrType'].mode()[0])
hp['MasVnrArea']=hp['MasVnrArea'].fillna(hp['MasVnrArea'].mean())
hp['BsmtQual']=hp['BsmtQual'].fillna(hp['BsmtQual'].mode()[0])
hp['BsmtCond']=hp['BsmtCond'].fillna(hp['BsmtCond'].mode()[0])
hp['BsmtExposure']=hp['BsmtExposure'].fillna(hp['BsmtExposure'].mode()[0])
hp['BsmtFinType1']=hp['BsmtFinType1'].fillna(hp['BsmtFinType1'].mode()[0])
hp['BsmtFinType2']=hp['BsmtFinType2'].fillna(hp['BsmtFinType2'].mode()[0])
hp['Electrical']=hp['Electrical'].fillna(hp['Electrical'].mode()[0])
hp['FireplaceQu']=hp['FireplaceQu'].fillna(hp['FireplaceQu'].mode()[0])
hp['GarageType']=hp['GarageType'].fillna(hp['GarageType'].mode()[0])
hp['GarageYrBlt']=hp['GarageYrBlt'].fillna(hp['GarageYrBlt'].mean())
hp['GarageFinish']=hp['GarageFinish'].fillna(hp['GarageFinish'].mode()[0])
hp['GarageQual']=hp['GarageQual'].fillna(hp['GarageQual'].mode()[0])
hp['GarageCond']=hp['GarageCond'].fillna(hp['GarageCond'].mode()[0])

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
# lets converting the object data type into int data type
hp['MSZoning']=le.fit_transform(hp['MSZoning'])
hp['Street']=le.fit_transform(hp['Street'])
hp['LotShape']=le.fit_transform(hp['LotShape'])
hp['LandContour']=le.fit_transform(hp['LandContour'])
hp['Utilities']=le.fit_transform(hp['Utilities'])
hp['LotConfig']=le.fit_transform(hp['LotConfig'])
hp['LandSlope']=le.fit_transform(hp['LandSlope'])
hp['Neighborhood']=le.fit_transform(hp['Neighborhood'])
hp['Condition1']=le.fit_transform(hp['Condition1'])
hp['Condition2']=le.fit_transform(hp['Condition2'])
hp['BldgType']=le.fit_transform(hp['BldgType'])
hp['HouseStyle']=le.fit_transform(hp['HouseStyle'])
hp['OverallQual']=le.fit_transform(hp['OverallQual'])
hp['OverallCond']=le.fit_transform(hp['OverallCond'])
hp['RoofStyle']=le.fit_transform(hp['RoofStyle'])
hp['RoofMatl']=le.fit_transform(hp['RoofMatl'])
hp['Exterior1st']=le.fit_transform(hp['Exterior1st'])
hp['Exterior2nd']=le.fit_transform(hp['Exterior2nd'])
hp['MasVnrType']=le.fit_transform(hp['MasVnrType'])
hp['ExterQual']=le.fit_transform(hp['ExterQual'])
hp['ExterCond']=le.fit_transform(hp['ExterCond'])
hp['Foundation']=le.fit_transform(hp['Foundation'])
hp['BsmtQual']=le.fit_transform(hp['BsmtQual'])
hp['BsmtCond']=le.fit_transform(hp['BsmtCond'])
hp['BsmtExposure']=le.fit_transform(hp['BsmtExposure'])
hp['BsmtFinType1']=le.fit_transform(hp['BsmtFinType1'])
hp['BsmtFinType2']=le.fit_transform(hp['BsmtFinType2'])
hp['Heating']=le.fit_transform(hp['Heating'])
hp['HeatingQC']=le.fit_transform(hp['HeatingQC'])
hp['CentralAir']=le.fit_transform(hp['CentralAir'])
hp['Electrical']=le.fit_transform(hp['Electrical'])
hp['KitchenQual']=le.fit_transform(hp['KitchenQual'])
hp['Functional']=le.fit_transform(hp['Functional'])
hp['FireplaceQu']=le.fit_transform(hp['FireplaceQu'])
hp['GarageType']=le.fit_transform(hp['GarageType'])
hp['GarageFinish']=le.fit_transform(hp['GarageFinish'])
hp['GarageQual']=le.fit_transform(hp['GarageQual'])
hp['GarageCond']=le.fit_transform(hp['GarageCond'])
hp['PavedDrive']=le.fit_transform(hp['PavedDrive'])
hp['SaleType']=le.fit_transform(hp['SaleType'])
hp['SaleCondition']=le.fit_transform(hp['SaleCondition'])

# %%
# Droping the columns because we have more null values in the data
del(hp['Alley'])
del(hp['PoolQC'])
del(hp['Fence'])
del(hp['MiscFeature'])
hp.drop(['GarageYrBlt'],axis=1,inplace=True)

# %%
# finding the new shape of the data
hp.shape
# Out:
# (1460, 76)

# %%
# finding the null values present or not
print(hp.isnull().sum())
print('\n')
print(sns.heatmap(hp.isnull()))
# its showing that there is no null values in the data
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 76, dtype: int64
#
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
# finding the statisticals description of the data
hp.describe()
# Out:
#                 Id   MSSubClass     MSZoning  LotFrontage        LotArea  \
# count  1460.000000  1460.000000  1460.000000  1460.000000    1460.000000
# mean    730.500000    56.897260     3.028767    70.049958   10516.828082
# std     421.610009    42.300571     0.632017    22.024023    9981.264932
# min       1.000000    20.000000     0.000000    21.000000    1300.000000
# 25%     365.750000    20.000000     3.000000    60.000000    7553.500000
# 50%     730.500000    50.000000     3.000000    70.049958    9478.500000
# 75%    1095.250000    70.000000     3.000000    79.000000   11601.500000
# max    1460.000000   190.000000     4.000000   313.000000  215245.000000
#
#             Street     LotShape  LandContour    Utilities    LotConfig  ...  \
# count  1460.000000  1460.000000  1460.000000  1460.000000  1460.000000  ...
# mean      0.995890     1.942466     2.777397     0.000685     3.019178  ...
# std       0.063996     1.409156     0.707666     0.026171     1.622634  ...
# ...

# %%
# finding the coorelation of the data
hp.corr()
# Out:
#                      Id  MSSubClass  MSZoning  LotFrontage   LotArea  \
# Id             1.000000    0.011156 -0.006096    -0.009601 -0.033226
# MSSubClass     0.011156    1.000000  0.035900    -0.357056 -0.139781
# MSZoning      -0.006096    0.035900  1.000000    -0.106363 -0.034452
# LotFrontage   -0.009601   -0.357056 -0.106363     1.000000  0.306795
# LotArea       -0.033226   -0.139781 -0.034452     0.306795  1.000000
# ...                 ...         ...       ...          ...       ...
# MoSold         0.021172   -0.013585 -0.031496     0.010158  0.001205
# YrSold         0.000712   -0.021407 -0.020628     0.006768 -0.014261
# SaleType       0.019773    0.012464  0.097437    -0.030846  0.012292
# SaleCondition -0.005806   -0.024940  0.009494     0.058464  0.034169
# SalePrice     -0.021917   -0.084284 -0.166872     0.334901  0.263843
#
#                  Street  LotShape  LandContour     Utilities  LotConfig  ...  \
# ...

# %%
sns.heatmap(hp.corr())

# %%
# finding the skewness within the dataset
hp.skew()
# there is more skewness present in the data
# Out:
# Id                0.000000
# MSSubClass        1.407657
# MSZoning         -1.735395
# LotFrontage       2.384950
# LotArea          12.207688
#                    ...
# MoSold            0.212053
# YrSold            0.096269
# SaleType         -3.868638
# SaleCondition    -2.741167
# SalePrice         1.882876
# Length: 76, dtype: float64

# %%
# using for loop we are trying to extract the skewness
for i in hp.columns:
    if hp.skew().loc[i]>0.55:
        hp[i]=np.log1p(hp[i])

# %% [markdown]
# # Visualization of the Data set

# %%
# finding the outliers in  the data
for i in hp.describe().columns:
    sns.boxplot(hp[i].dropna())
    plt.show()
# graphical representation is showing that many outliers present in the data

# %%
collist=hp.columns.values
ncol=12
nrow=10

# %%
# finding the outliers using subplots 
plt.figure(figsize=(ncol,4*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(hp[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %%
# finding the histogram analysis of the data
for i in hp.describe().columns:
    plt.hist(hp[i].dropna())
    plt.show()

# %% [markdown]
# # Finding the distribution of skewness in the data using Univariate and Bivariate Analysis

# %%
sns.distplot(hp['MSSubClass'])

# %%
sns.distplot(hp['LotFrontage'])

# %%
sns.distplot(hp['LotArea'])

# %%
sns.distplot(hp['LotShape'])

# %%
sns.distplot(hp['Neighborhood'])

# %%
sns.distplot(hp['HouseStyle'])

# %%
sns.distplot(hp['BsmtExposure'])

# %%
hp.plot(kind='scatter',x='HeatingQC',y='CentralAir',stacked=True)

# %%
sns.lineplot(x='HeatingQC',y='CentralAir',data=hp)

# %%
sns.distplot(hp['KitchenQual'])

# %%
sns.lineplot(x='GarageCond',y='GarageQual',data=hp)

# %%
sns.lineplot(x='OverallQual',y='OverallCond',data=hp)

# %% [markdown]
# # Seprating the input and output variable from the data

# %%
x=hp.drop('SalePrice',axis=1)
x.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage   LotArea  Street  LotShape  \
# 0   1    4.110874         3     4.189655  9.042040       1         3
# 1   2    3.044522         3     4.394449  9.169623       1         3
# 2   3    4.110874         3     4.234107  9.328212       1         0
# 3   4    4.262680         3     4.110874  9.164401       1         0
# 4   5    4.110874         3     4.442651  9.565284       1         0
#
#    LandContour  Utilities  LotConfig  ...  OpenPorchSF  EnclosedPorch  \
# 0            3        0.0          4  ...     4.127134       0.000000
# 1            3        0.0          2  ...     0.000000       0.000000
# 2            3        0.0          4  ...     3.761200       0.000000
# 3            3        0.0          0  ...     3.583519       5.609472
# 4            3        0.0          2  ...     4.442651       0.000000
#
#    3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  \
# ...

# %%
y=hp['SalePrice']
y.head()
# Out:
# 0    12.247699
# 1    12.109016
# 2    12.317171
# 3    11.849405
# 4    12.429220
# Name: SalePrice, dtype: float64

# %%
# training the model
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)
print(x_train.shape , x_test.shape)
print(y_train.shape , y_test.shape)
# Out:
# (1168, 75) (292, 75)
# (1168,) (292,)

# %%
# fitting the model
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_
# Out:
# array([-8.36627993e-06, -5.92386796e-03, -2.08339123e-02, -3.69979106e-02,
#         7.20267738e-02,  5.97287866e-02, -2.08422884e-03,  1.21718142e-02,
#        -2.62469730e-01, -7.61298373e-04,  6.48900590e-02,  5.96567103e-04,
#         3.46932518e-02, -9.08637633e-02, -1.14853763e-02, -2.05444466e-03,
#         5.65868717e-02,  2.17732266e-01,  1.35617474e-03,  8.49783167e-04,
#         1.63953205e-02,  7.02015030e-02, -6.80231969e-03,  4.85135333e-03,
#         8.31036548e-03, -1.53638475e-03, -1.67200498e-02,  3.49429296e-03,
#         1.71041300e-02, -2.52088780e-02,  1.75234662e-02, -9.14275232e-03,
#         8.02328993e-04,  7.59846593e-03,  2.42137981e-03, -9.61799976e-04,
#        -3.35787989e-03,  1.64258224e-02, -3.74086025e-02, -4.53760188e-03,
#         5.75611999e-02, -3.74374902e-03, -2.31702182e-02, -1.26077919e-02,
#        -7.90305040e-03,  5.08227802e-01,  5.61946108e-02,  1.56394389e-02,
# ...

# %%
lr.intercept_
# Out:
# 12.772317161791793

# %%
lr.score(x_train,y_train)
# Out:
# 0.901754560757994

# %% [markdown]
# # Predicting and analysing the model with various modeling techniques

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import cross_val_score
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=r_state)
    lr.fit(x_train,y_train)
    pre=lr.predict(x_test)
    r2_scr=r2_score(y_test,pre)
    print('R2 Score is cooresponding to',r_state,'is :',r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
        
print()
print('Max R2 is Cooresponding to',final_r_state,'is:',max_r_score)
# Out:
# R2 Score is cooresponding to 42 is : 0.8912701220809595
# R2 Score is cooresponding to 43 is : 0.8721490901713711
# R2 Score is cooresponding to 44 is : 0.8951072848573602
# R2 Score is cooresponding to 45 is : 0.8847277225298901
# R2 Score is cooresponding to 46 is : 0.9098191673044536
# R2 Score is cooresponding to 47 is : 0.8006900016400785
# R2 Score is cooresponding to 48 is : 0.8321758831179813
# R2 Score is cooresponding to 49 is : 0.8996294303426813
# R2 Score is cooresponding to 50 is : 0.9008243404481833
# R2 Score is cooresponding to 51 is : 0.8567472030703489
# R2 Score is cooresponding to 52 is : 0.9079892700859266
# R2 Score is cooresponding to 53 is : 0.8569064101423904
# R2 Score is cooresponding to 54 is : 0.8256761665646078
# R2 Score is cooresponding to 55 is : 0.8836183088630714
# R2 Score is cooresponding to 56 is : 0.8017721633090447
# R2 Score is cooresponding to 57 is : 0.8560958524063073
# R2 Score is cooresponding to 58 is : 0.8872021741136953
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
lgr=LinearRegression()
dtr=DecisionTreeRegressor()
rfr=RandomForestRegressor()
abr=AdaBoostRegressor()
gbr=GradientBoostingRegressor()
knr=KNeighborsRegressor()
models=[]
models.append(('LinearRegression',lgr))
models.append(('DecisionTreeRegressor',dtr))
models.append(('RandomForestRegressor',rfr))
models.append(('AdaBoostRegressor',abr))
models.append(('GradientBoostingRegressor',gbr))
models.append(('KNeighborsRegressor',knr))

# %%
Model=[]
r2score=[]
RMSE=[]
CVS=[]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=63)
for i,model in models:
    print('***************',i,'****************','\n')
    Model.append(i)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    r2s=r2_score(y_test,pre)
    print('R2 Score is ',r2s,'\n')
    r2score.append(r2s*100)
    rmse=np.sqrt(mean_squared_error(y_test,pre))
    print('RMSE is ',rmse,'\n')
    RMSE.append(rmse)
    sc=cross_val_score(model,x,y,cv=5,scoring='r2').mean()
    print('Cross Validation Score is ',sc,'\n')
    CVS.append(sc*100)
# Out:
# *************** LinearRegression ****************
#
# R2 Score is  0.9275808109357364
#
# RMSE is  0.10535126786474985
#
# Cross Validation Score is  0.8835827014964159
#
# *************** DecisionTreeRegressor ****************
#
# R2 Score is  0.7230925964571511
#
# RMSE is  0.2060061669921953
#
# Cross Validation Score is  0.7414689924522236
#
# *************** RandomForestRegressor ****************
#
# R2 Score is  0.9132249135050884
#
# RMSE is  0.11532154854519502
#
# Cross Validation Score is  0.871308557457257
#
# *************** AdaBoostRegressor ****************
#
# R2 Score is  0.8596759483757643
#
# RMSE is  0.14664896281166365
#
# Cross Validation Score is  0.8090077244443753
#
# *************** GradientBoostingRegressor ****************
#
# R2 Score is  0.929739670540695
#
# RMSE is  0.10376909492549159
#
# Cross Validation Score is  0.8967032477950457
#
# *************** KNeighborsRegressor ****************
#
# R2 Score is  0.47556593546519754
#
# ...

# %%
result=pd.DataFrame({'Model':Model,'R2_Score':r2score,'RMSE':RMSE,'CVS':CVS})
result
# Out:
#                        Model   R2_Score      RMSE        CVS
# 0           LinearRegression  92.758081  0.105351  88.358270
# 1      DecisionTreeRegressor  72.309260  0.206006  74.146899
# 2      RandomForestRegressor  91.322491  0.115322  87.130856
# 3          AdaBoostRegressor  85.967595  0.146649  80.900772
# 4  GradientBoostingRegressor  92.973967  0.103769  89.670325
# 5        KNeighborsRegressor  47.556594  0.283503  41.048092

# %%
from sklearn.externals import joblib
joblib.dump(gbr,'House_Pred.csv')
# Out:
# ['House_Pred.csv']
