# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %%
ss=pd.read_csv('Skyserver.csv')
ss
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# ...

# %%
# Finding the column name of the data
ss.columns
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %%
# finding the shape of the data
ss.shape
# Out:
# (10000, 18)

# %%
# finding the top skyserver data form the dataset
ss.head(10)
# Out:
#           objid          ra       dec         u         g         r         i  \
# 0  1.237650e+18  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342
# 1  1.237650e+18  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922
# 2  1.237650e+18  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732
# 3  1.237650e+18  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233
# 4  1.237650e+18  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492
# 5  1.237650e+18  183.847174  0.173694  19.43133  18.46779  18.16451  18.01475
# 6  1.237650e+18  183.864379  0.019201  19.38322  17.88995  17.10537  16.66393
# 7  1.237650e+18  183.900081  0.187473  18.97993  17.84496  17.38022  17.20673
# 8  1.237650e+18  183.924588  0.097246  17.90616  16.97172  16.67541  16.53776
# 9  1.237650e+18  183.973498  0.081626  18.67249  17.71375  17.49362  17.28284
#
#           z  run  rerun  camcol  field     specobjid   class  redshift  plate  \
# ...

# %%
# finding the bottom data in skyserver data
ss.tail(10)
# Out:
#              objid          ra        dec         u         g         r  \
# 9990  1.237650e+18  131.115570  51.447136  18.17880  16.71989  16.04004
# 9991  1.237650e+18  131.113284  51.490710  18.58806  16.61418  15.62407
# 9992  1.237650e+18  131.202820  51.499011  19.02614  18.13936  17.82697
# 9993  1.237650e+18  131.398915  51.533706  17.79613  16.02621  15.15955
# 9994  1.237650e+18  131.175791  51.679675  19.52000  18.46195  18.11317
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# 9990  15.66338  15.38130  1345    301       3    160  5.033570e+17  GALAXY
# ...

# %%
# finding the null values from the data set
ss.isnull().sum()
# Out:
# objid        0
# ra           0
# dec          0
# u            0
# g            0
# r            0
# i            0
# z            0
# run          0
# rerun        0
# camcol       0
# field        0
# specobjid    0
# class        0
# redshift     0
# plate        0
# mjd          0
# fiberid      0
# dtype: int64

# %%
# it show that there is no null values present in the data set
sns.heatmap(ss.isnull())

# %%
# finding the data type of each columns
ss.columns.to_series().groupby(ss.dtypes).groups
# Out:
# {dtype('int64'): Index(['run', 'rerun', 'camcol', 'field', 'plate', 'mjd', 'fiberid'], dtype='object'),
#  dtype('float64'): Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'specobjid', 'redshift'], dtype='object'),
#  dtype('O'): Index(['class'], dtype='object')}

# %%
# finding the coorelation of the skyserver data
ss.corr()
# Out:
#                   objid            ra           dec             u  \
# objid      1.000000e+00  2.524419e-14 -1.937483e-15  5.581214e-14
# ra         2.524419e-14  1.000000e+00  3.596046e-03  3.123756e-02
# dec       -1.937483e-15  3.596046e-03  1.000000e+00  3.527932e-02
# u          5.581214e-14  3.123756e-02  3.527932e-02  1.000000e+00
# g          1.001149e-13  4.390863e-02  6.187471e-02  8.492320e-01
# r          2.995673e-14  4.710290e-02  6.340395e-02  6.923790e-01
# i          2.212198e-14  4.573107e-02  5.829189e-02  6.026302e-01
# z         -4.107700e-14  4.294957e-02  5.687030e-02  5.514828e-01
# run       -1.553011e-14 -9.274056e-02  7.783849e-01  3.822910e-02
# rerun               NaN           NaN           NaN           NaN
# camcol     1.921887e-15 -6.293831e-03  1.146139e-01  9.944672e-03
# field      5.938881e-16  5.946996e-01 -1.314714e-01  8.547880e-03
# specobjid -1.829075e-15 -9.532711e-02  8.834533e-02 -1.294293e-01
# ...

# %%
# analaysing the cooreltion of data
sns.heatmap(ss.corr())
# it shows that there is no coorelation between rerun column so i am droping this column

# %%
# droping the rerun column from the data set
del(ss['rerun'])

# %% [markdown]
# # Finding the outliers from the data set

# %%
# it shows that there are some outliers present in the data
for i in ss.describe().columns:
    sns.boxplot(ss[i].dropna())
    plt.show()

# %% [markdown]
# # Finding the destribution of skewness in the data

# %%
sns.distplot(ss['fiberid'])

# %%
sns.distplot(ss['mjd'])

# %%
sns.distplot(ss['plate'])

# %%
sns.distplot(ss['ra'])

# %%
sns.distplot(ss['dec'])

# %%
# converting the object data type into int
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
ss['class']=le.fit_transform(ss['class'])

# %%
del(ss['objid'])

# %%
del(ss['specobjid'])

# %%
sns.distplot(ss['class'])

# %%
sns.distplot(ss['z'])

# %%
sns.lineplot(x='run',y='class',data=ss)

# %%
sns.lineplot(x='u',y='class',data=ss)

# %%
sns.pairplot(ss)

# %% [markdown]
# # Removing skewness and outliers from the data set

# %%
ss.skew()
# Out:
# ra         -1.227350
# dec         1.191544
# u          -1.219795
# g          -0.536293
# r          -0.021673
# i           0.286442
# z           0.214313
# run         0.412555
# camcol     -0.100220
# field       0.249795
# class       0.169292
# redshift    4.265729
# plate       1.794609
# mjd         1.039610
# fiberid     0.308053
# dtype: float64

# %%
from scipy.stats import zscore
z=np.abs(zscore(ss))
z
# Out:
# array([[0.16745842, 0.58492272, 1.03148637, ..., 1.03148936, 1.30931064,
#         0.66863177],
#        [0.16886159, 0.58311429, 0.05243046, ..., 0.63621258, 0.87919741,
#         0.91101156],
#        [0.17057433, 0.58347525, 0.92156796, ..., 0.65633905, 0.60919097,
#         0.77527888],
#        ...,
#        [0.92039468, 1.46090664, 0.16753826, ..., 3.26608697, 2.69309363,
#         1.3036668 ],
#        [0.92197294, 1.46432109, 0.31801835, ..., 0.56688806, 0.70581092,
#         0.60143828],
#        [0.91804124, 1.46639319, 0.79229193, ..., 0.56688806, 0.70581092,
#         0.5820479 ]])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  45,  109,  129, ..., 9992, 9994, 9997], dtype=int64), array([11, 11, 11, ..., 12, 12, 12], dtype=int64))

# %%
ssd=ss[(z<3).all(axis=1)]
ssd
# Out:
#               ra        dec         u         g         r         i         z  \
# 0     183.531326   0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1     183.598371   0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2     183.680207   0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3     183.870529   0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4     183.883288   0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
# ...          ...        ...       ...       ...       ...       ...       ...
# 9993  131.398915  51.533706  17.79613  16.02621  15.15955  14.71488  14.33840
# 9995  131.316413  51.539547  18.81777  17.47053  16.91508  16.68305  16.50570
# 9996  131.306083  51.671341  18.27255  17.43849  17.07692  16.71661  16.69897
# 9998  131.477151  51.753068  18.88287  17.91068  17.53152  17.36284  17.13988
# 9999  131.665012  51.805307  19.27586  17.37829  16.30542  15.83548  15.50588
#
# ...

# %%
print(ss.shape , ssd.shape)
# Out:
# (10000, 15) (8698, 15)

# %% [markdown]
# # Seprating the Input and output variables from the data

# %%
x=ssd.drop('class',axis=1)
x.head(10)
# Out:
#            ra       dec         u         g         r         i         z  \
# 0  183.531326  0.089693  19.47406  17.04240  15.94699  15.50342  15.22531
# 1  183.598371  0.135285  18.66280  17.21449  16.67637  16.48922  16.39150
# 2  183.680207  0.126185  19.38298  18.19169  17.47428  17.08732  16.80125
# 3  183.870529  0.049911  17.76536  16.60272  16.16116  15.98233  15.90438
# 4  183.883288  0.102557  17.55025  16.26342  16.43869  16.55492  16.61326
# 5  183.847174  0.173694  19.43133  18.46779  18.16451  18.01475  18.04155
# 6  183.864379  0.019201  19.38322  17.88995  17.10537  16.66393  16.36955
# 7  183.900081  0.187473  18.97993  17.84496  17.38022  17.20673  17.07071
# 8  183.924588  0.097246  17.90616  16.97172  16.67541  16.53776  16.47596
# 9  183.973498  0.081626  18.67249  17.71375  17.49362  17.28284  17.22644
#
#    run  camcol  field  redshift  plate    mjd  fiberid
# 0  752       4    267 -0.000009   3306  54922      491
# ...

# %%
y=ssd['class']
y.head()
# Out:
# 0    2
# 1    2
# 2    0
# 3    2
# 4    2
# Name: class, dtype: int32

# %%
# now training the model with input and output variable
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)
print(x_train.shape , x_test.shape)
print(y_train.shape , y_test.shape)
# Out:
# (6958, 14) (1740, 14)
# (6958,) (1740,)

# %%
# fitting the model
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
from sklearn.linear_model import LogisticRegression
lgr=LogisticRegression()
lgr.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import cross_val_score
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=r_state)
    lgr.fit(x_train,y_train)
    pre=lgr.predict(x_test)
    r2_scr=r2_score(y_test,pre)
    print('R2 Score is cooresponding to',r_state,'is :',r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
        
print()
print('Max R2 is Cooresponding to',final_r_state,'is:',max_r_score)
# Out:
# R2 Score is cooresponding to 42 is : 0.4054669703872438
# R2 Score is cooresponding to 43 is : 0.39005068526866815
# R2 Score is cooresponding to 44 is : 0.45762815479907637
# R2 Score is cooresponding to 45 is : 0.37795707323005456
# R2 Score is cooresponding to 46 is : 0.4151239744224554
# R2 Score is cooresponding to 47 is : 0.43319441977981554
# R2 Score is cooresponding to 48 is : 0.4042047511925074
# R2 Score is cooresponding to 49 is : 0.4091220335020126
# R2 Score is cooresponding to 50 is : 0.4170698206441843
# R2 Score is cooresponding to 51 is : 0.36964045211995145
# R2 Score is cooresponding to 52 is : 0.362737274126432
# R2 Score is cooresponding to 53 is : 0.3778086798583865
# R2 Score is cooresponding to 54 is : 0.4135308634322661
# R2 Score is cooresponding to 55 is : 0.3664518811057993
# R2 Score is cooresponding to 56 is : 0.3855695005480989
# R2 Score is cooresponding to 57 is : 0.4321744721191427
# R2 Score is cooresponding to 58 is : 0.44421651564214637
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
lgr=LinearRegression()
dtr=DecisionTreeRegressor()
rfr=RandomForestRegressor()
abr=AdaBoostRegressor()
gbr=GradientBoostingRegressor()
knr=KNeighborsRegressor()
models=[]
models.append(('LinearRegression',lgr))
models.append(('DecisionTreeRegressor',dtr))
models.append(('RandomForestRegressor',rfr))
models.append(('AdaBoostRegressor',abr))
models.append(('GradientBoostingRegressor',gbr))
models.append(('KNeighborsRegressor',knr))

# %%
Model=[]
r2score=[]
RMSE=[]
CVS=[]
for i,model in models:
    print('***************',i,'****************','\n')
    Model.append(i)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    r2s=r2_score(y_test,pre)
    print('R2 Score is ',r2s,'\n')
    r2score.append(r2s*100)
    rmse=np.sqrt(mean_squared_error(y_test,pre))
    print('RMSE is ',rmse,'\n')
    RMSE.append(rmse)
    sc=cross_val_score(model,x,y,cv=5,scoring='r2').mean()
    print('Cross Validation Score is ',sc,'\n')
    CVS.append(sc*100)
# Out:
# *************** LinearRegression ****************
#
# R2 Score is  0.6941834004107721
#
# RMSE is  0.5325495636264045
#
# Cross Validation Score is  0.6836383883868539
#
# *************** DecisionTreeRegressor ****************
#
# R2 Score is  0.9745917006678672
#
# RMSE is  0.1535031543350318
#
# Cross Validation Score is  0.9695500744207566
#
# *************** RandomForestRegressor ****************
#
# R2 Score is  0.9810715606551025
#
# RMSE is  0.132491162142903
#
# Cross Validation Score is  0.9813500826118453
#
# *************** AdaBoostRegressor ****************
#
# R2 Score is  0.9527547509165084
#
# RMSE is  0.2093189642688307
#
# Cross Validation Score is  0.92463316043728
#
# *************** GradientBoostingRegressor ****************
#
# R2 Score is  0.9857557571802064
#
# RMSE is  0.11493417686872459
#
# Cross Validation Score is  0.9864794020505663
#
# *************** KNeighborsRegressor ****************
#
# R2 Score is  0.49416414032048506
#
# ...

# %% [markdown]
# # Using Classification method for analaysing the model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score,GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report,roc_curve,auc

# %%
lgr=LogisticRegression()
dtc=DecisionTreeClassifier()
knn=KNeighborsClassifier()
sv=SVC()
rfc=RandomForestClassifier()
abc=AdaBoostClassifier()
gbc=GradientBoostingClassifier()
models=[]
models.append(('LogisticRegression',lgr))
models.append(('DecisionTreeClassifier',dtc))
models.append(('KNeighborsClassifier',knn))
models.append(('SVC',sv))
models.append(('RandomForestClassifier',rfc))
models.append(('AdaBoostClassifier',abc))
models.append(('GradientBoostingClassifier',gbc))

# %%
Model=[]
score=[]
cvs=[]
for i,model in models:
    print('******************',i,'*******************','\n')
    Model.append(i)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    AS=accuracy_score(y_test,pre)
    print('Accuracy Score is ',AS,'\n')
    score.append(AS*100)
    CM=confusion_matrix(y_test,pre)
    print('Confusion Matrix is \n',CM,'\n')
    print('Classification Report is',classification_report(y_test,pre),'\n')
    cs=cross_val_score(model,x,y,cv=5,scoring='accuracy').mean()
    print('Cross Validation Score is ',cs,'\n')
    cvs.append(cs*100)
# Out:
# ****************** LogisticRegression *******************
#
# Accuracy Score is  0.8261929641239986
#
# Confusion Matrix is
#  [[1578    0   39]
#  [ 125    0    6]
#  [ 329    0  794]]
#
# Classification Report is               precision    recall  f1-score   support
#
#            0       0.78      0.98      0.86      1617
#            1       0.00      0.00      0.00       131
#            2       0.95      0.71      0.81      1123
#
#     accuracy                           0.83      2871
#    macro avg       0.57      0.56      0.56      2871
# weighted avg       0.81      0.83      0.80      2871
#
#
# Cross Validation Score is  0.826052824651504
#
# ****************** DecisionTreeClassifier *******************
#
# Accuracy Score is  0.9829327760362243
#
# Confusion Matrix is
#  [[1596   19    2]
#  [  25  106    0]
#  [   3    0 1120]]
#
# Classification Report is               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1617
# ...

# %%
result=pd.DataFrame({'Model':Model,'Accuracy Score':score,'CVS':cvs})
result
# Out:
#                         Model  Accuracy Score        CVS
# 0          LogisticRegression       82.619296  82.605282
# 1      DecisionTreeClassifier       98.293278  98.148883
# 2        KNeighborsClassifier       81.539533  77.754371
# 3                         SVC       82.584465  82.593788
# 4      RandomForestClassifier       98.746082  98.827276
# 5          AdaBoostClassifier       83.176594  76.136675
# 6  GradientBoostingClassifier       98.815744  98.907755
