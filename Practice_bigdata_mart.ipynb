# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
bigdata_test=pd.read_csv('bigdatamart_test.csv')
bigdata_test
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
bigdata_test.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type'],
#       dtype='object')

# %%
bigdata_test.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type
# ...

# %%
bigdata_test.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5676           FDB58         10.5          Regular         0.013496
# 5677           FDD47          7.6          Regular         0.142991
# 5678           NCO17         10.0          Low Fat         0.073529
# 5679           FDJ26         15.3          Regular         0.000000
# 5680           FDU37          9.5          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 5676         Snack Foods  141.3154            OUT046
# 5677       Starchy Foods  169.1448            OUT018
# 5678  Health and Hygiene  118.7440            OUT045
# 5679              Canned  214.6218            OUT017
# 5680              Canned   79.7960            OUT045
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5676                       1997       Small               Tier 1
# 5677                       2009      Medium               Tier 3
# ...

# %%
bigdata_train=pd.read_csv('bigdatamart_train.csv')
bigdata_train
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
bigdata_train.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
bigdata_train.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
bigdata_train.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
# finding shape of bigdataset train and test
print('bigdatatest_shape',bigdata_test.shape)
print('bigdatatrain_shape',bigdata_train.shape)
# Out:
# bigdatatest_shape (5681, 11)
# bigdatatrain_shape (8523, 12)

# %%
# finding the isnull values
print('bigdatatest --\n',bigdata_test.isnull().sum())
print('\n')
print('bigdatatrain -- \n',bigdata_train.isnull().sum())
# Out:
# bigdatatest --
#  Item_Identifier                 0
# Item_Weight                   976
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  1606
# Outlet_Location_Type            0
# Outlet_Type                     0
# dtype: int64
#
#
# bigdatatrain --
#  Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# statistical description of bigdata_test dataset 
bigdata_test.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year
# count  4705.000000      5681.000000  5681.000000                5681.000000
# mean     12.695633         0.065684   141.023273                1997.828903
# std       4.664849         0.051252    61.809091                   8.372256
# min       4.555000         0.000000    31.990000                1985.000000
# 25%       8.645000         0.027047    94.412000                1987.000000
# 50%      12.500000         0.054154   141.415400                1999.000000
# 75%      16.700000         0.093463   186.026600                2004.000000
# max      21.350000         0.323637   266.588400                2009.000000

# %%
# statistical description of bigdata_train dataset 
bigdata_train.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
# adding both train and test dataset
df=pd.concat([bigdata_test,bigdata_train],ignore_index=True)
df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDW58       20.750          Low Fat         0.007565
# 1               FDW14        8.300              reg         0.038428
# 2               NCN55       14.600          Low Fat         0.099575
# 3               FDQ58        7.315          Low Fat         0.015388
# 4               FDY38          NaN          Regular         0.118599
# ...               ...          ...              ...              ...
# 14199           FDF22        6.865          Low Fat         0.056783
# 14200           FDS36        8.380          Regular         0.046982
# 14201           NCJ29       10.600          Low Fat         0.035186
# 14202           FDN46        7.210          Regular         0.145221
# 14203           DRG01       14.800          Low Fat         0.044878
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 0             Snack Foods  107.8622            OUT049
# ...

# %%
df.shape
# Out:
# (14204, 12)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58       20.750          Low Fat         0.007565  Snack Foods
# 1           FDW14        8.300              reg         0.038428        Dairy
# 2           NCN55       14.600          Low Fat         0.099575       Others
# 3           FDQ58        7.315          Low Fat         0.015388  Snack Foods
# 4           FDY38          NaN          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007         NaN
# 2  241.7538            OUT010                       1998         NaN
# 3  155.0340            OUT017                       2007         NaN
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
df.tail()
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 14199           FDF22        6.865          Low Fat         0.056783
# 14200           FDS36        8.380          Regular         0.046982
# 14201           NCJ29       10.600          Low Fat         0.035186
# 14202           FDN46        7.210          Regular         0.145221
# 14203           DRG01       14.800          Low Fat         0.044878
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 14199         Snack Foods  214.5218            OUT013
# 14200        Baking Goods  108.1570            OUT045
# 14201  Health and Hygiene   85.1224            OUT035
# 14202         Snack Foods  103.1332            OUT018
# 14203         Soft Drinks   75.4670            OUT046
#
#        Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 14199                       1987        High               Tier 3
# 14200                       2002         NaN               Tier 2
# ...

# %%
# finding null values
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
# finding null values using heatmap
sns.heatmap(df.isnull())

# %% [markdown]
# # Analysing the data using in graphical representation

# %%
for i in bigdata_train.describe().columns:
    sns.distplot(bigdata_train[i].dropna())
    plt.show()

# %%
for i in bigdata_train.describe().columns:
    sns.boxplot(bigdata_train[i].dropna())
    plt.show()

# %%
bigdata_train.Item_Type.value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.countplot(bigdata_train.Item_Type)

# %%
plt.figure(figsize=(8,6))
sns.countplot(bigdata_train.Outlet_Size)

# %%
bigdata_train.Outlet_Size.value_counts()
# Out:
# Medium    2793
# Small     2388
# High       932
# Name: Outlet_Size, dtype: int64

# %%
plt.figure(figsize=(7,5))
sns.countplot(bigdata_train.Outlet_Location_Type)

# %%
bigdata_train.Outlet_Location_Type.value_counts()
# Out:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64

# %%
plt.figure(figsize=(9,5))
sns.countplot(bigdata_train.Outlet_Type)

# %%
bigdata_train.Outlet_Type.value_counts()
# Out:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %%
plt.figure(figsize=(13,9))
plt.xlabel('Item_Weight')
plt.ylabel('Item_outlet_sales')
plt.title('Item weight and Item Outlet Sales analysis')
sns.scatterplot(x='Item_Weight',y='Item_Outlet_Sales',hue='Item_Type',data=bigdata_train)

# %%
plt.figure(figsize=(13,9))
plt.xlabel('Item_Visibility')
plt.ylabel('Item_outlet_sales')
plt.title('Item visibility and Item Outlet Sales analysis')
sns.scatterplot(x='Item_Visibility',y='Item_Outlet_Sales',hue='Item_Type',data=bigdata_train)

# %%
plt.figure(figsize=(13,9))
plt.xlabel('Item_Visibility')
plt.ylabel('Maximum Retail Price')
plt.title('Item visibility and Maximum Retail Price')
sns.scatterplot(bigdata_train.Item_Visibility ,bigdata_train.Item_MRP, alpha= 0.3)

# %%
bigdata_train.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027141
# Item_Visibility              -0.014048         1.000000 -0.001315
# Item_MRP                      0.027141        -0.001315  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005020
# Item_Outlet_Sales             0.014123        -0.128625  0.567574
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005020           0.567574
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
sns.heatmap(bigdata_train.corr())

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
df['Item_Weight'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 14199    False
# 14200    False
# 14201    False
# 14202    False
# 14203    False
# Name: Item_Weight, Length: 14204, dtype: bool

# %%
# filling the missing values 
df['Item_Weight'].fillna(df['Item_Weight'].mean(),inplace=True)

# %%
df['Outlet_Size'].isnull()
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 14199    False
# 14200     True
# 14201    False
# 14202    False
# 14203    False
# Name: Outlet_Size, Length: 14204, dtype: bool

# %%
df['Outlet_Size'].fillna('medium',inplace=True)

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# dtype: int64

# %%
df['Item_Visibility'].value_counts()
# Out:
# 0.000000    879
# 0.076841      3
# 0.076792      3
# 0.077169      3
# 0.077290      3
#            ...
# 0.038405      1
# 0.093686      1
# 0.066296      1
# 0.047743      1
# 0.120667      1
# Name: Item_Visibility, Length: 13006, dtype: int64

# %%
df['Item_Visibility'].fillna('medium',inplace=True)

# %%
df['Outlet_Establishment_Year'].value_counts()
# Out:
# 1985    2439
# 1987    1553
# 1999    1550
# 1997    1550
# 2004    1550
# 2002    1548
# 2009    1546
# 2007    1543
# 1998     925
# Name: Outlet_Establishment_Year, dtype: int64

# %%
df['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    2013
# Snack Foods              1989
# Household                1548
# Frozen Foods             1426
# Dairy                    1136
# Baking Goods             1086
# Canned                   1084
# Health and Hygiene        858
# Meat                      736
# Soft Drinks               726
# Breads                    416
# Hard Drinks               362
# Others                    280
# Starchy Foods             269
# Breakfast                 186
# Seafood                    89
# Name: Item_Type, dtype: int64

# %%
df['Item_Identifier'].value_counts()
# Out:
# FDU52    10
# FDM22    10
# FDX21    10
# NCO18    10
# FDE45    10
#          ..
# FDS22     7
# FDH58     7
# FDL50     7
# NCL42     7
# FDM52     7
# Name: Item_Identifier, Length: 1559, dtype: int64

# %%
df['New_Item_Type']=df['Item_Identifier'].apply(lambda x: x[0:2])

# %%
df['New_Item_Type']=df['New_Item_Type'].map({'FD':'Food','NC':'Non-Consumable','DR':'Drinks'})

# %%
df['New_Item_Type'].value_counts()
# Out:
# Food              10201
# Non-Consumable     2686
# Drinks             1317
# Name: New_Item_Type, dtype: int64

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility    Item_Type  \
# 0           FDW58    20.750000          Low Fat         0.007565  Snack Foods
# 1           FDW14     8.300000              reg         0.038428        Dairy
# 2           NCN55    14.600000          Low Fat         0.099575       Others
# 3           FDQ58     7.315000          Low Fat         0.015388  Snack Foods
# 4           FDY38    12.792854          Regular         0.118599        Dairy
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  107.8622            OUT049                       1999      Medium
# 1   87.3198            OUT017                       2007      medium
# 2  241.7538            OUT010                       1998      medium
# 3  155.0340            OUT017                       2007      medium
# 4  234.2300            OUT027                       1985      Medium
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales   New_Item_Type
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
change=['Item_Identifier','Item_Fat_Content','Outlet_Identifier','Outlet_Size','Outlet_Location_Type','Outlet_Type','New_Item_Type']
for i in change:
    df[i]=le.fit_transform(df[i])

# %%
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0             1114    20.750000                 1         0.007565
# 1             1078     8.300000                 4         0.038428
# 2             1420    14.600000                 1         0.099575
# 3              817     7.315000                 1         0.015388
# 4             1197    12.792854                 2         0.118599
#
#      Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Snack Foods  107.8622                  9                       1999
# 1        Dairy   87.3198                  2                       2007
# 2       Others  241.7538                  0                       1998
# 3  Snack Foods  155.0340                  2                       2007
# 4        Dairy  234.2300                  5                       1985
#
#    Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  \
# ...

# %%
df['Item_Outlet_Sales'].isnull()
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 14199    False
# 14200    False
# 14201    False
# 14202    False
# 14203    False
# Name: Item_Outlet_Sales, Length: 14204, dtype: bool

# %%
df['Item_Outlet_Sales'].fillna(df['Item_Outlet_Sales'].mean(),inplace=True)

# %%
df.head()
# Out:
#    Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0             1114    20.750000                 1         0.007565
# 1             1078     8.300000                 4         0.038428
# 2             1420    14.600000                 1         0.099575
# 3              817     7.315000                 1         0.015388
# 4             1197    12.792854                 2         0.118599
#
#      Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# 0  Snack Foods  107.8622                  9                       1999
# 1        Dairy   87.3198                  2                       2007
# 2       Others  241.7538                  0                       1998
# 3  Snack Foods  155.0340                  2                       2007
# 4        Dairy  234.2300                  5                       1985
#
#    Outlet_Size  Outlet_Location_Type  Outlet_Type  Item_Outlet_Sales  \
# ...

# %%
df.drop(['Item_Identifier','Item_Type','Outlet_Establishment_Year'],axis=1,inplace=True)

# %%
df.skew()
# Out:
# Item_Weight             0.111314
# Item_Fat_Content        0.996640
# Item_Visibility         1.195175
# Item_MRP                0.130728
# Outlet_Identifier      -0.059994
# Outlet_Size            -0.131825
# Outlet_Location_Type   -0.209053
# Outlet_Type             0.927344
# Item_Outlet_Sales       1.520025
# New_Item_Type           0.117284
# dtype: float64

# %%
for col in df.columns:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# Item_Weight             0.111314
# Item_Fat_Content       -0.331504
# Item_Visibility         1.038885
# Item_MRP                0.130728
# Outlet_Identifier      -0.059994
# Outlet_Size            -0.131825
# Outlet_Location_Type   -0.209053
# Outlet_Type            -0.235873
# Item_Outlet_Sales      -1.585887
# New_Item_Type           0.117284
# dtype: float64

# %%
x=df.drop(['Item_Outlet_Sales'],axis=1)
x.head()
# Out:
#    Item_Weight  Item_Fat_Content  Item_Visibility  Item_MRP  \
# 0    20.750000          0.693147         0.007536  107.8622
# 1     8.300000          1.609438         0.037708   87.3198
# 2    14.600000          0.693147         0.094924  241.7538
# 3     7.315000          0.693147         0.015271  155.0340
# 4    12.792854          1.098612         0.112077  234.2300
#
#    Outlet_Identifier  Outlet_Size  Outlet_Location_Type  Outlet_Type  \
# 0                  9            1                     0     0.693147
# 1                  2            3                     1     0.693147
# 2                  0            3                     2     0.000000
# 3                  2            3                     1     0.693147
# 4                  5            1                     2     1.386294
#
#    New_Item_Type
# 0              1
# 1              1
# 2              2
# 3              1
# 4              1

# %%
y=df['Item_Outlet_Sales']
y.head()
# Out:
# 0    7.68813
# 1    7.68813
# 2    7.68813
# 3    7.68813
# 4    7.68813
# Name: Item_Outlet_Sales, dtype: float64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lrg=LinearRegression()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (9516, 9)
# (4688, 9)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (9516,)
# (4688,)

# %%
lrg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lrg.coef_
# Out:
# array([-2.09260026e-03,  2.46619299e-02, -8.55176966e-01,  5.09486191e-03,
#        -1.93015451e-03,  9.52905529e-03, -1.51632257e-01,  1.12841921e+00,
#         5.76125340e-04])

# %%
lrg.intercept_
# Out:
# 6.1347957973351415

# %%
lrg.score(x_train,y_train)
# Out:
# 0.365147139081182

# %%
lrg_pred=lrg.predict(x_test)
lrg_pred
# Out:
# array([7.89666609, 8.30465888, 6.93399693, ..., 7.14743617, 8.12004872,
#        7.53288004])

# %%
from sklearn import linear_model
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=r_state)
    lrg=linear_model.LinearRegression()
    lrg.fit(x_train,y_train)
    y_pred=lrg.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    print('r2_score coorsponding to random state is ',r_state,'is:',r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
    
print()
print()
print('Max r2 is cooresponding to ',final_r_state,'is:',max_r_score)
# Out:
# r2_score coorsponding to random state is  42 is: 0.3381730422044875
# r2_score coorsponding to random state is  43 is: 0.34231429609576847
# r2_score coorsponding to random state is  44 is: 0.3478691748202365
# r2_score coorsponding to random state is  45 is: 0.37122596379862427
# r2_score coorsponding to random state is  46 is: 0.34173948509247
# r2_score coorsponding to random state is  47 is: 0.3443463826101908
# r2_score coorsponding to random state is  48 is: 0.34256308901713683
# r2_score coorsponding to random state is  49 is: 0.34966165504481894
# r2_score coorsponding to random state is  50 is: 0.3320855000683022
# r2_score coorsponding to random state is  51 is: 0.3458033793271683
# r2_score coorsponding to random state is  52 is: 0.3551437457471094
# r2_score coorsponding to random state is  53 is: 0.36992012990796985
# r2_score coorsponding to random state is  54 is: 0.3557786190198847
# r2_score coorsponding to random state is  55 is: 0.34176141561661344
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=67,test_size=.20)
lrg=linear_model.LinearRegression()
lrg.fit(x_train,y_train)
lrg_pred=lrg.predict(x_test)
print('r2_score is ',r2_score(y_test,lrg_pred))
print('RSME is ',np.sqrt(mean_squared_error(y_test,lrg_pred)))
# Out:
# r2_score is  0.3906000977248921
# RSME is  0.6501243309763609

# %%
from sklearn.linear_model import LinearRegression
lrg=LinearRegression()
lrg.fit(x_train,y_train)
lrg_pre=dtc.predict(x_test)
print('Mean squared error is ',mean_squared_error(y_test,lrg_pre))
print('RMSE is ',np.sqrt(mean_squared_error(y_test,lrg_pre)))
print('predicted values are ',lrg_pre)
# Out:
# Mean squared error is  0.7506346208762937
# RMSE is  0.8663917248429222
# predicted values are  [5.30201054 6.45337552 7.68812957 ... 6.8953948  7.67393636 5.7618023 ]

# %%
from sklearn.tree import DecisionTreeRegressor
dtc=DecisionTreeRegressor()
dtc.fit(x_train,y_train)
dtc_pre=dtc.predict(x_test)
print('Mean squared error is ',mean_squared_error(y_test,dtc_pre))
print('RMSE is ',np.sqrt(mean_squared_error(y_test,dtc_pre)))
print('predicted values are ',dtc_pre)
# Out:
# Mean squared error is  0.7672594850386701
# RMSE is  0.8759334935020296
# predicted values are  [6.67452402 6.45337552 7.68812957 ... 6.8953948  7.67393636 5.7618023 ]

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
rfr_pre=dtc.predict(x_test)
print('Mean squared error is ',mean_squared_error(y_test,rfr_pre))
print('RMSE is ',np.sqrt(mean_squared_error(y_test,rfr_pre)))
# Out:
# Mean squared error is  0.7672594850386701
# RMSE is  0.8759334935020296
