# %%
# importing Required library 

from selenium import webdriver
import pandas as pd
from bs4 import BeautifulSoup
from time import sleep
import time
from datetime import date

driver=webdriver.Edge(r"C:\Users\PANKAJ\Downloads\msedgedriver.exe")
driver.get("https://in.indeed.com/jobs?q=Data+Scientist&l=Delhi")
# finding the details which are scraped from the web server
jobtitle = []
company = []
location = []
daysposted = []
salary = []
description = []
crawl_timestamp = []
crawl_date = []

# %%
jobs = driver.find_elements_by_class_name('result')
# lets scrap the data from the server with the help of for loop
for job in jobs:
    
    res= job.get_attribute('innerHTML')
    jb = BeautifulSoup(res,'html.parser')

    try:
        title = jb.find("a" ,class_="jobtitle").text.replace('\n',' ')
        jobtitle.append(title)
    except:
        jobtitle.append('  ')
 
    try:
        com= jb.find("span" ,class_="company").text.replace('\n',' ')
        company.append(com)
    except:
        company.append(' ')

    try:
        lo = jb.find("span" ,class_="location accessible-contrast-color-location").text.replace('\n',' ')
        location.append(lo)
    except:
        location.append(' ')      
      
    try:
        sal = jb.find("span" ,class_="salaryText").text.replace('\n',' ')
        salary.append(sal)
    except:
        salary.append('Not Mentioned')
       
    try:
        day = jb.find("span" ,class_="date").text.replace('\n',' ')
        daysposted.append(day)
    except:
        daysposted.append(' ')
     
    try:
        jo = jb.find("div" ,class_="summary").text.replace('\n',' ')
        description.append(jo)
    except:
        description.append('----')
# lets scrap the date time form the server with the help of loop            
    time.sleep(2)
            
    t = time.gmtime()
    crawl_timestamp.append(time.strftime("%Y-%m-%d %H:%M:%S", t))

    today = date.today()    
    t1 = today.strftime("%d %B %Y")
    crawl_date.append(t1)

# %%
# lets finding the leangth of the scraped attributes so that we can create the dataframe of the result 
print(len(jobtitle),len(company),len(location),len(daysposted),len(salary),len(description),len(crawl_timestamp),len(crawl_date))
# Out:
# 15 15 15 15 15 15 15 15

# %%
# lets create the indeed data table
indeed =pd.DataFrame({ 'Job Name' : jobtitle ,'Job Location' : location,'Company Name' : company ,' Salary' :salary ,'Post Days' : daysposted ,'Time': crawl_timestamp , ' Date' : crawl_date ,'Job Description' : description  })
indeed
# Out:
#                                              Job Name  \
# 0                                      Data Scientist
# 1                                      Data Scientist
# 2                                      Data Scientist
# 3                           Machine Learning Engineer
# 4                           Data Analytics Internship
# 5                                      Data Scientist
# 6    Machine Learning (ML)/Natural Language Proces...
# 7                                      Data Scientist
# 8                                      Data Scientist
# 9                                      DATA SCIENTIST
# 10   Fresher - Internship - Business Analytics / D...
# 11                                  Sr.Data Scientist
# 12                             Manager Data Scientist
# 13                                     Data Scientist
# 14                        Machine Learning Internship
#
#                     Job Location                                 Company Name  \
# 0                   Delhi, Delhi                                  AI Engineer
# 1               New Delhi, Delhi       Terra Economics & Analytics Lab (TEAL)
# 2                   Delhi, Delhi                                NatWest Group
# 3                   Delhi, Delhi                        VNU SOFTWARE Pvt Ltd.
# 4                   Delhi, Delhi                                   Tsukiindia
# 5                   Delhi, Delhi                               Team Computers
# 6               New Delhi, Delhi                   Pointers Digitech Pvt Ltd.
# 7                          Delhi                 RGF Professional Recruitment
# 8   Defence Colony, Delhi, Delhi                              Mahajan Imaging
# 9                   Delhi, Delhi                        Innefu Labs Pvt. Ltd.
# 10                  Delhi, Delhi   Shri TirupatiI Balaji Education Foundation
# 11                  Delhi, Delhi                        Innefu Labs Pvt. Ltd.
# 12                  Delhi, Delhi                        Innefu Labs Pvt. Ltd.
# 13              New Delhi, Delhi                                      Ank Aha
# 14                  Delhi, Delhi                        TestRight Nanosystems
#
#                            Salary     Post Days                 Time  \
# 0       ₹17,000 - ₹25,000 a month   28 days ago  2020-12-31 15:56:06
# 1                   Not Mentioned  30+ days ago  2020-12-31 15:56:09
# 2                   Not Mentioned  30+ days ago  2020-12-31 15:56:11
# 3       ₹25,000 - ₹40,000 a month  30+ days ago  2020-12-31 15:56:13
# 4                  ₹4,000 a month    6 days ago  2020-12-31 15:56:15
# 5                   Not Mentioned    2 days ago  2020-12-31 15:56:17
# 6    ₹4,00,000 - ₹5,00,000 a year    2 days ago  2020-12-31 15:56:19
# 7                   Not Mentioned  30+ days ago  2020-12-31 15:56:21
# 8                   Not Mentioned  30+ days ago  2020-12-31 15:56:23
# 9                   Not Mentioned  30+ days ago  2020-12-31 15:56:25
# 10   ₹3,60,000 - ₹5,90,000 a year   29 days ago  2020-12-31 15:56:27
# 11                  Not Mentioned  30+ days ago  2020-12-31 15:56:29
# 12                  Not Mentioned  30+ days ago  2020-12-31 15:56:31
# 13                  Not Mentioned  30+ days ago  2020-12-31 15:56:33
# 14                ₹10,000 a month   11 days ago  2020-12-31 15:56:35
#
#                 Date                                    Job Description
# 0   31 December 2020    Ability to use data visualization tools to s...
# 1   31 December 2020    Creating compelling data visualizations and ...
# 2   31 December 2020    This is an opportunity to participate in the...
# 3   31 December 2020    We are looking for experience Machine Learni...
# 4   31 December 2020    Working as a data analyst and mining data 2....
# 5   31 December 2020    Extraction of actionable data from unstructu...
# 6   31 December 2020    Supervising the data acquisition process if ...
# 7   31 December 2020    Looking for Data Scientist with one of the l...
# 8   31 December 2020    Responsible for driving Mahajan Imaging's ne...
# 9   31 December 2020    Keep up-to-date with latest technology trend...
# 10  31 December 2020    Call / whatsapp Ketan - 9808811409 / Rashmi ...
# 11  31 December 2020    Must be able to handle deployment complexiti...
# 12  31 December 2020    Must be able to handle deployment complexiti...
# 13  31 December 2020    Ensure data integrity and consistency across...
# 14  31 December 2020    How would you know if that jacket is genuine...
