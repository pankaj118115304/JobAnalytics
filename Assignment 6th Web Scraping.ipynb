# %%
# Importing the Libraries
import pandas as pd
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
import time
import string
from datetime import date
from datetime import datetime
start_page=0
end_page=7
# Giving the name of the website which we have to scrap
def data_sci(url):   # Scraping data analyst profile for delhi location
    #Loading Driver
    driver=webdriver.Edge(r"C:\Users\PANKAJ\Downloads\msedgedriver.exe")
    # Getting the URL
    driver.get(url)
    # we have to scrap the below attached details
    Job_Name=[]
    Job_Location=[]
    Company_Name=[]
    Salary=[]
    Job_Desc=[]
    Post_Days=[]
    crawl_timestamp=[]
    crawl_date=[]
    for page in range(start_page,end_page+1):
        name=driver.find_elements_by_xpath("//h2[@class='title']")
        for n in name:
            n_name=n.text
            Job_Name.append(n_name)
            JN=pd.DataFrame(Job_Name)
            JN=JN.rename({0: 'Job Name'},axis=1)
        location=driver.find_elements_by_xpath("//span[@class='location accessible-contrast-color-location']")
        for ln in location:
            ln_name=ln.text
            Job_Location.append(ln_name)
            LN=pd.DataFrame(Job_Location)
            LN=LN.rename({0: 'Job Location'},axis=1)
        company=driver.find_elements_by_xpath("//div[@class='sjcl']/div[1]")
        for c in company:
            c_name=c.text
            Company_Name.append(c_name)
            CN=pd.DataFrame(Company_Name)
            CN=CN.rename({0: 'Company Name'},axis=1)
        salary=driver.find_elements_by_xpath("//span[@class='salary no-wrap']")
        for s in salary:
            s_avg=s.text
            Salary.append(s_avg)
            S=pd.DataFrame(Salary)
            S=S.rename({0: 'Salary P/M/Y'},axis=1)
        desc=driver.find_elements_by_xpath("//div[@class='summary']/ul/li[1]")
        for d in desc:
            d_name=d.text
            Job_Desc.append(d_name)
            JD=pd.DataFrame(Job_Desc)
            JD=JD.rename({0: 'Job Description'},axis=1)
        postday=driver.find_elements_by_xpath("//span[@class='date ']")
        for p in postday:
            p_day=p.text
            Post_Days.append(p_day)
            PD=pd.DataFrame(Post_Days)
            PD=PD.rename({0: 'Post Days'},axis=1)
       # importing the date and time from the library      
            now=datetime.now()
            crawl_timestamp.append(now.strftime("%H:%M:%S"))
            tim=pd.DataFrame(crawl_timestamp)
            tim=tim.rename({0: 'Time'},axis=1)
            today=date.today()
            crawl_date.append(today.strftime("%d/%m/%Y"))
            dt=pd.DataFrame(crawl_date)
            dt=dt.rename({0: 'Date'},axis=1)
        # now lets scrap the data from the server            
        nxt_button=driver.find_element_by_xpath("//ul[@class='pagination-list']/li[6]/a[@href]")
        nxt_button.click()
        time.sleep(7)

# now lets create the data table and adding the columns into the table
    indeed=pd.concat([JN,LN,CN,S,JD,PD,dt,tim],axis=1)
    indeed.to_csv('Data Analyst indeed', index = True)
    print(indeed)
# Calling Function
data_sci("https://in.indeed.com/jobs?q=data+analyst&l=delhi")
# Out:
#                                             Job Name           Job Location  \
# 0                                  Data Analyst\nnew  Kalkaji, Delhi, Delhi
# 1                                  Data Analyst\nnew           Delhi, Delhi
# 2                                  Data Analyst\nnew           Delhi, Delhi
# 3                                Data Analyst Intern       New Delhi, Delhi
# 4              Senior Market Research Analyst –\nnew  Kalkaji, Delhi, Delhi
# ..                                               ...                    ...
# 115                        Data Analytics Internship           Delhi, Delhi
# 116                             Digital Data Analyst       New Delhi, Delhi
# 117                              Research Analyst II       New Delhi, Delhi
# 118  Global Mobility Tax Data and Technology Analyst       New Delhi, Delhi
# 119                                          Analyst                  Delhi
#
#                                           Company Name  \
# 0                        Dimentics Info Tech Pvt. Ltd.
# 1                                              Unihelp
# 2                       Shriram Automall India Ltd 3.6
# 3                                              TryKiya
# 4                        Dimentics Info Tech Pvt. Ltd.
# ..                                                 ...
# 115                 Accord Innovations Private Limited
# 116                                       Asymmetrique
# 117  IFPRI (International Food Policy Research Inst...
# 118                    The Boston Consulting Group 4.2
# 119                                             BD 3.8
#
#                   Salary P/M/Y  \
# 0    ₹25,000 - ₹42,000 a month
# 1    ₹15,000 - ₹30,000 a month
# 2              ₹50,000 a month
# 3               ₹5,000 a month
# 4    ₹25,000 - ₹42,000 a month
# ..                         ...
# 115                        NaN
# 116                        NaN
# 117                        NaN
# 118                        NaN
# 119                        NaN
#
#                                        Job Description     Post Days  \
# 0    Acquire data from primary or secondary data so...   Just posted
# 1    We take data-related projects to provide valua...    7 days ago
# 2    Assists business analysts with finding pattern...    5 days ago
# 3    Acquire data from primary or secondary data so...   20 days ago
# 4    Interpret data, formulate reports and make rec...   Just posted
# ..                                                 ...           ...
# 115  Analytical and logical skills Knowledge or exp...   25 days ago
# 116  3 - 4 years practical experience on data proce...  30+ days ago
# 117          Reply to internal/external data requests.   27 days ago
# 118  You will own the data retention and data priva...  30+ days ago
# 119  This role would focus on using SAP for data ne...   19 days ago
#
#            Date      Time
# 0    05/01/2021  21:38:14
# 1    05/01/2021  21:38:14
# 2    05/01/2021  21:38:14
# 3    05/01/2021  21:38:14
# 4    05/01/2021  21:38:14
# ..          ...       ...
# 115  05/01/2021  21:39:21
# 116  05/01/2021  21:39:21
# 117  05/01/2021  21:39:21
# 118  05/01/2021  21:39:21
# 119  05/01/2021  21:39:21
#
# [120 rows x 8 columns]
