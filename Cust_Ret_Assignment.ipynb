# %%
# importing the necessary library 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# loading the dataset
cr=pd.read_csv('Cust_R.csv')
cr
# Out:
#      1Gender of respondent  2 How old are you?   \
# 0                        0                    3
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# ..                     ...                  ...
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 0                                   Delhi
# 1                                   Delhi
# 2                           Greater Noida
# 3                                 Karnal
# 4                              Bangalore
# ..                                    ...
# 264                                 Solan
# ...

# %%
# finding the all columns name present in the dataset
cr.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
# finding the datatype of the columns
cr.dtypes
# Out:
# 1Gender of respondent                                                    int64
# 2 How old are you?                                                       int64
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                               int64
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
# finding the object datatypes column names
for i in cr.columns:
    if cr[i].dtypes=='object':
        print(i) # all the colums need to convert into integer format
# Out:
# 3 Which city do you shop online from?
# From the following, tick any (or all) of the online retailers you have shopped from;
# Easy to use website or application
# Visual appealing web-page layout
# Wild variety of product on offer
# Complete, relevant description information of products
# Fast loading website speed of website and application
# Reliability of the website or application
# Quickness to complete purchase
# Availability of several payment options
# Speedy order delivery
# Privacy of customers’ information
# Security of customer financial information
# Perceived Trustworthiness
# Presence of online assistance through multi-channel
# Longer time to get logged in (promotion, sales period)
# Longer time in displaying graphics and photos (promotion, sales period)
# Late declaration of price (promotion, sales period)
# Longer page loading time (promotion, sales period)
# Limited mode of payment on most products (promotion, sales period)
# Longer delivery period
# ...

# %%
# finding the top 5 web sites data
cr.head()
# Out:
#    1Gender of respondent  2 How old are you?   \
# 0                      0                    3
# 1                      1                    2
# 2                      1                    2
# 3                      0                    2
# 4                      1                    2
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#    5 Since How Long You are Shopping Online ?  \
# 0                                           5
# ...

# %%
# finding the bottom 5 web sites data
cr.tail()
# Out:
#      1Gender of respondent  2 How old are you?   \
# 264                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#     3 Which city do you shop online from?  \
# 264                                 Solan
# 265                             Ghaziabad
# 266                            Bangalore
# 267                                 Solan
# 268                             Ghaziabad
#
#      4 What is the Pin Code of where you shop online from?  \
# 264                                             173212
# 265                                             201008
# 266                                             560010
# 267                                             173229
# 268                                             201009
#
#      5 Since How Long You are Shopping Online ?  \
# ...

# %%
# finding the shape of the data
cr.shape
# Out:
# (269, 71)

# %%
# finding the null values present in the data set
print(cr.isnull().sum())
print('\n')
print(sns.heatmap(cr.isnull())) # it is showing that there is no null value present in the data set
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64
#
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
# converting the whole object data into ionteger data
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
cr['3 Which city do you shop online from?']=le.fit_transform(cr['3 Which city do you shop online from?'])
cr['From the following, tick any (or all) of the online retailers you have shopped from;']=le.fit_transform(cr['From the following, tick any (or all) of the online retailers you have shopped from;'])
cr['Easy to use website or application']=le.fit_transform(cr['Easy to use website or application'])
cr['Visual appealing web-page layout']=le.fit_transform(cr['Visual appealing web-page layout'])
cr['Wild variety of product on offer']=le.fit_transform(cr['Wild variety of product on offer'])
cr['Complete, relevant description information of products']=le.fit_transform(cr['Complete, relevant description information of products'])
cr['Fast loading website speed of website and application']=le.fit_transform(cr['Fast loading website speed of website and application'])
cr['Reliability of the website or application']=le.fit_transform(cr['Reliability of the website or application'])
cr['Quickness to complete purchase']=le.fit_transform(cr['Quickness to complete purchase'])
cr['Speedy order delivery']=le.fit_transform(cr['Speedy order delivery'])
cr['Availability of several payment options']=le.fit_transform(cr['Availability of several payment options'])
cr['Privacy of customers’ information']=le.fit_transform(cr['Privacy of customers’ information'])
cr['Security of customer financial information']=le.fit_transform(cr['Security of customer financial information'])
cr['Perceived Trustworthiness']=le.fit_transform(cr['Perceived Trustworthiness'])
cr['Presence of online assistance through multi-channel']=le.fit_transform(cr['Presence of online assistance through multi-channel'])
cr['Longer time to get logged in (promotion, sales period)']=le.fit_transform(cr['Longer time to get logged in (promotion, sales period)'])
cr['Longer time in displaying graphics and photos (promotion, sales period)']=le.fit_transform(cr['Longer time in displaying graphics and photos (promotion, sales period)'])
cr['Late declaration of price (promotion, sales period)']=le.fit_transform(cr['Late declaration of price (promotion, sales period)'])
cr['Longer page loading time (promotion, sales period)']=le.fit_transform(cr['Longer page loading time (promotion, sales period)'])
cr['Limited mode of payment on most products (promotion, sales period)']=le.fit_transform(cr['Limited mode of payment on most products (promotion, sales period)'])
cr['Longer delivery period']=le.fit_transform(cr['Longer delivery period'])
cr['Change in website/Application design']=le.fit_transform(cr['Change in website/Application design'])
cr['Frequent disruption when moving from one page to another']=le.fit_transform(cr['Frequent disruption when moving from one page to another'])
cr['Website is as efficient as before']=le.fit_transform(cr['Website is as efficient as before'])
cr['Which of the Indian online retailer would you recommend to a friend?']=le.fit_transform(cr['Which of the Indian online retailer would you recommend to a friend?'])

# %%
# finding the skewness present in the data
cr.skew()
# it is showing that there is less skewness present in the data
# Out:
# 1Gender of respondent                                                  -0.723007
# 2 How old are you?                                                      0.063243
# 3 Which city do you shop online from?                                   0.313729
# 4 What is the Pin Code of where you shop online from?                   1.748322
# 5 Since How Long You are Shopping Online ?                             -0.554705
#                                                                           ...
# Longer delivery period                                                 -0.147702
# Change in website/Application design                                    0.354163
# Frequent disruption when moving from one page to another               -0.100608
# Website is as efficient as before                                       0.662084
# Which of the Indian online retailer would you recommend to a friend?    0.583614
# Length: 71, dtype: float64

# %%
# finding the statistical description of the data
cr.describe()
# Out:
#        1Gender of respondent  2 How old are you?   \
# count             269.000000           269.000000
# mean                0.669145             2.959108
# std                 0.471398             1.066012
# min                 0.000000             1.000000
# 25%                 0.000000             2.000000
# 50%                 1.000000             3.000000
# 75%                 1.000000             4.000000
# max                 1.000000             5.000000
#
#        3 Which city do you shop online from?  \
# count                             269.000000
# mean                                4.494424
# std                                 3.187687
# min                                 0.000000
# 25%                                 2.000000
# 50%                                 4.000000
# 75%                                 7.000000
# max                                10.000000
#
#        4 What is the Pin Code of where you shop online from?  \
# ...

# %%
sns.heatmap(cr.describe())

# %% [markdown]
# # Finding the outliers in the data

# %%
# finding the outliers in the dataset
for i in cr.describe().columns:
    sns.boxplot(cr[i].dropna())
    plt.show() # box plot visulization is showing very less outliers in the data

# %% [markdown]
# # finding distribution of skewness using univariate and bivariate analysis

# %%
sns.distplot(cr['3 Which city do you shop online from?'])

# %%
sns.distplot(cr['5 Since How Long You are Shopping Online ?'])

# %%
sns.distplot(cr['6 How many times you have made an online purchase in the past 1 year?'])

# %%
sns.distplot(cr['32 Shopping online is convenient and flexible'])

# %%
sns.distplot(cr['Fast loading website speed of website and application'])

# %%
sns.distplot(cr['Security of customer financial information'])

# %%
sns.distplot(cr['Easy to use website or application'])

# %%
sns.distplot(cr['Which of the Indian online retailer would you recommend to a friend?'])

# %%
cr.plot(kind='scatter',x='1Gender of respondent',y='Which of the Indian online retailer would you recommend to a friend?',stacked=True)

# %%
cr.plot(kind='scatter',x='1Gender of respondent',y='25 Convenient Payment methods',stacked=True)

# %%
cr.plot(kind='scatter', x='1Gender of respondent', y='Easy to use website or application',stacked=True)

# %%
sns.lineplot(data=cr,x='1Gender of respondent',y='25 Convenient Payment methods')

# %%
sns.lineplot(x='1Gender of respondent', y='Easy to use website or application',data=cr)

# %%
sns.lineplot(x='1Gender of respondent',y='Which of the Indian online retailer would you recommend to a friend?',data=cr)

# %%
cr.dtypes
# Out:
# 1Gender of respondent                                                   int64
# 2 How old are you?                                                      int64
# 3 Which city do you shop online from?                                   int32
# 4 What is the Pin Code of where you shop online from?                   int64
# 5 Since How Long You are Shopping Online ?                              int64
#                                                                         ...
# Longer delivery period                                                  int32
# Change in website/Application design                                    int32
# Frequent disruption when moving from one page to another                int32
# Website is as efficient as before                                       int32
# Which of the Indian online retailer would you recommend to a friend?    int32
# Length: 71, dtype: object

# %% [markdown]
# # removing the putliers and skewness in the data

# %%
from scipy.stats import zscore
z=np.abs(zscore(cr))
z
# Out:
# array([[1.42213639, 0.03843148, 0.78397694, ..., 1.40519246, 0.98469733,
#         1.52727829],
#        [0.70316744, 0.9013929 , 0.78397694, ..., 0.16163354, 0.52322768,
#         0.25533445],
#        [0.70316744, 0.9013929 , 0.15539334, ..., 0.94504654, 0.98469733,
#         1.10329701],
#        ...,
#        [0.70316744, 0.97825586, 1.41256055, ..., 1.33675303, 0.98469733,
#         1.01660938],
#        [0.70316744, 1.84121727, 1.73035746, ..., 0.55334004, 1.32265095,
#         1.01660938],
#        [0.70316744, 0.97825586, 0.46968514, ..., 1.40519246, 0.98469733,
#         1.01660938]])

# %%
thresold=3
print(np.where(z>3))
# Out:
# (array([  0,   7,   7,   7,  13,  21,  21,  21,  27,  31,  38,  38,  38,
#         44,  52,  52,  52,  53,  53,  53,  59,  64,  64,  64,  65,  65,
#         65,  66,  70,  70,  70,  74,  82,  82,  82,  88, 101, 103, 103,
#        103, 110, 110, 110, 112, 113, 122, 124, 124, 124, 131, 131, 131,
#        133, 134, 143, 143, 143, 147, 151, 153, 156, 156, 156, 157, 157,
#        157, 158, 158, 158, 172, 182, 182, 182, 193, 196, 198, 198, 198,
#        203, 203, 203, 206, 206, 206, 207, 210, 214, 231, 231, 231, 232,
#        232, 232, 233, 233, 233, 245, 247, 250, 259, 263, 263, 263, 264,
#        264, 264], dtype=int64), array([32, 17, 21, 26, 28, 17, 21, 26, 28, 32, 17, 21, 26, 32, 17, 21, 26,
#        17, 21, 26, 32, 17, 21, 26, 17, 21, 26, 32, 17, 21, 26, 28, 10, 32,
#        35, 39, 28, 10, 32, 35, 17, 21, 26, 39, 32, 28, 10, 32, 35, 17, 21,
#        26, 39, 32, 17, 21, 26, 28, 28, 28, 17, 21, 26, 17, 21, 26, 17, 21,
# ...

# %%
CR=cr[(z<3).all(axis=1)]
CR
# Out:
#      1Gender of respondent  2 How old are you?   \
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# 5                        1                    3
# ..                     ...                  ...
# 262                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#      3 Which city do you shop online from?  \
# 1                                        2
# 2                                        4
# 3                                        6
# 4                                        0
# 5                                        9
# ..                                     ...
# 262                                      0
# ...

# %%
# finding the shape of old and new data set
print('Shape of old dataset is',cr.shape)
print('Shape of new dataset is',CR.shape)
# Out:
# Shape of old dataset is (269, 71)
# Shape of new dataset is (215, 71)

# %% [markdown]
# # seprating the input and output variables from the dataset

# %%
# Scale the x-axis and y-axis data
from sklearn.preprocessing import MinMaxScaler,StandardScaler
ss=StandardScaler()

# %%
# input variable are
x=CR.iloc[:,0:-1]
x
# Out:
#      1Gender of respondent  2 How old are you?   \
# 1                        1                    2
# 2                        1                    2
# 3                        0                    2
# 4                        1                    2
# 5                        1                    3
# ..                     ...                  ...
# 262                      1                    2
# 265                      1                    3
# 266                      1                    4
# 267                      1                    1
# 268                      1                    4
#
#      3 Which city do you shop online from?  \
# 1                                        2
# 2                                        4
# 3                                        6
# 4                                        0
# 5                                        9
# ..                                     ...
# 262                                      0
# ...

# %%
# output variable is 
y=CR['Which of the Indian online retailer would you recommend to a friend?']
y
# Out:
# 1      3
# 2      5
# 3      1
# 4      3
# 5      4
#       ..
# 262    3
# 265    6
# 266    0
# 267    0
# 268    0
# Name: Which of the Indian online retailer would you recommend to a friend?, Length: 215, dtype: int32

# %%
# lets training the model with x-axis and y-axis 
from sklearn.model_selection import train_test_split
x_train,y_train,x_test,y_test=train_test_split(x,y,test_size=.20,random_state=42)
print(x_train.shape , x_test.shape)
print(y_train.shape , y_test.shape)
# Out:
# (172, 70) (172,)
# (43, 70) (43,)

# %%
# fitting the model
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# # Predicting and analysing the model with various modeling techniques

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.model_selection import cross_val_score
max_r_score=0
for r_state in range(42,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=r_state)
    lr.fit(x_train,y_train)
    pre=lr.predict(x_test)
    r2_scr=r2_score(y_test,pre)
    print('R2 Score is cooresponding to',r_state,'is :',r2_scr)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
        
print()
print('Max R2 is Cooresponding to',final_r_state,'is:',max_r_score)
# Out:
# R2 Score is cooresponding to 42 is : 1.0
# R2 Score is cooresponding to 43 is : 1.0
# R2 Score is cooresponding to 44 is : 1.0
# R2 Score is cooresponding to 45 is : 1.0
# R2 Score is cooresponding to 46 is : 1.0
# R2 Score is cooresponding to 47 is : 1.0
# R2 Score is cooresponding to 48 is : 1.0
# R2 Score is cooresponding to 49 is : 1.0
# R2 Score is cooresponding to 50 is : 1.0
# R2 Score is cooresponding to 51 is : 1.0
# R2 Score is cooresponding to 52 is : 1.0
# R2 Score is cooresponding to 53 is : 1.0
# R2 Score is cooresponding to 54 is : 1.0
# R2 Score is cooresponding to 55 is : 1.0
# R2 Score is cooresponding to 56 is : 1.0
# R2 Score is cooresponding to 57 is : 1.0
# R2 Score is cooresponding to 58 is : 1.0
# R2 Score is cooresponding to 59 is : 1.0
# R2 Score is cooresponding to 60 is : 1.0
# R2 Score is cooresponding to 61 is : 1.0
# R2 Score is cooresponding to 62 is : 1.0
# R2 Score is cooresponding to 63 is : 1.0
# R2 Score is cooresponding to 64 is : 1.0
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
lgr=LinearRegression()
dtr=DecisionTreeRegressor()
rfr=RandomForestRegressor()
abr=AdaBoostRegressor()
gbr=GradientBoostingRegressor()
knr=KNeighborsRegressor()
models=[]
models.append(('LinearRegression',lgr))
models.append(('DecisionTreeRegressor',dtr))
models.append(('RandomForestRegressor',rfr))
models.append(('AdaBoostRegressor',abr))
models.append(('GradientBoostingRegressor',gbr))
models.append(('KNeighborsRegressor',knr))

# %%
Model=[]
r2score=[]
RMSE=[]
CVS=[]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)
for i,model in models:
    print('***************',i,'****************','\n')
    Model.append(i)
    model.fit(x_train,y_train)
    pre=model.predict(x_test)
    r2s=r2_score(y_test,pre)
    print('R2 Score is ',r2s,'\n')
    r2score.append(r2s*100)
    rmse=np.sqrt(mean_squared_error(y_test,pre))
    print('RMSE is ',rmse,'\n')
    RMSE.append(rmse)
    sc=cross_val_score(model,x,y,cv=5,scoring='r2').mean()
    print('Cross Validation Score is ',sc,'\n')
    CVS.append(sc*100)
# Out:
# *************** LinearRegression ****************
#
# R2 Score is  1.0
#
# RMSE is  5.837421073358705e-12
#
# Cross Validation Score is  0.9995461594275433
#
# *************** DecisionTreeRegressor ****************
#
# R2 Score is  1.0
#
# RMSE is  0.0
#
# Cross Validation Score is  1.0
#
# *************** RandomForestRegressor ****************
#
# R2 Score is  0.9999679868969624
#
# RMSE is  0.013206763594884272
#
# Cross Validation Score is  0.9999030883753374
#
# *************** AdaBoostRegressor ****************
#
# R2 Score is  0.8672192488388691
#
# RMSE is  0.8505504491969387
#
# Cross Validation Score is  0.9664717366344471
#
# *************** GradientBoostingRegressor ****************
#
# R2 Score is  0.9999999808007493
#
# RMSE is  0.00032342579770419574
#
# Cross Validation Score is  0.9999489542239273
#
# *************** KNeighborsRegressor ****************
#
# R2 Score is  0.6938693666865198
#
# RMSE is  1.2914747294253133
#
# ...

# %%
result=pd.DataFrame({'Model':Model,'R2_Score':r2score,'RMSE':RMSE,'CVS':CVS})
result
# Out:
#                        Model    R2_Score          RMSE         CVS
# 0           LinearRegression  100.000000  5.837421e-12   99.954616
# 1      DecisionTreeRegressor  100.000000  0.000000e+00  100.000000
# 2      RandomForestRegressor   99.996799  1.320676e-02   99.990309
# 3          AdaBoostRegressor   86.721925  8.505504e-01   96.647174
# 4  GradientBoostingRegressor   99.999998  3.234258e-04   99.994895
# 5        KNeighborsRegressor   69.386937  1.291475e+00   60.769149

# %%
from sklearn.externals import joblib
joblib.dump(dtc,'Cust_Pred.csv')
# Out:
# ['Cust_Pred.csv']
